# %%
import pandas as pd
from sklearn.model_selection import train_test_split, GridSearchCV, RandomizedSearchCV 
from sklearn.tree import DecisionTreeClassifier 
from sklearn.ensemble import RandomForestClassifier 
from sklearn.metrics import accuracy_score, classification_report 
import seaborn as sns 
import matplotlib.pyplot as plt 

import warnings 
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('cancer dataset.csv')

# %%
df.head()
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
#    ...  texture_worst  perimeter_worst  area_worst  smoothness_worst  \
# 0  ...          17.33           184.60      2019.0            0.1622
# 1  ...          23.41           158.80      1956.0            0.1238
# 2  ...          25.53           152.50      1709.0            0.1444
# 3  ...          26.50            98.87       567.7            0.2098
# 4  ...          16.67           152.20      1575.0            0.1374
#
#    compactness_worst  concavity_worst  concave points_worst  symmetry_worst  \
# 0             0.6656           0.7119                0.2654          0.4601
# 1             0.1866           0.2416                0.1860          0.2750
# 2             0.4245           0.4504                0.2430          0.3613
# 3             0.8663           0.6869                0.2575          0.6638
# 4             0.2050           0.4000                0.1625          0.2364
#
#    fractal_dimension_worst  Unnamed: 32
# 0                  0.11890          NaN
# 1                  0.08902          NaN
# 2                  0.08758          NaN
# 3                  0.17300          NaN
# 4                  0.07678          NaN
#
# [5 rows x 33 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 569 entries, 0 to 568
# Data columns (total 33 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   id                       569 non-null    int64
#  1   diagnosis                569 non-null    object
#  2   radius_mean              569 non-null    float64
#  3   texture_mean             569 non-null    float64
#  4   perimeter_mean           569 non-null    float64
#  5   area_mean                569 non-null    float64
#  6   smoothness_mean          569 non-null    float64
#  7   compactness_mean         569 non-null    float64
#  8   concavity_mean           569 non-null    float64
#  9   concave points_mean      569 non-null    float64
#  10  symmetry_mean            569 non-null    float64
#  11  fractal_dimension_mean   569 non-null    float64
#  12  radius_se                569 non-null    float64
#  13  texture_se               569 non-null    float64
#  14  perimeter_se             569 non-null    float64
#  15  area_se                  569 non-null    float64
#  16  smoothness_se            569 non-null    float64
#  17  compactness_se           569 non-null    float64
#  18  concavity_se             569 non-null    float64
#  19  concave points_se        569 non-null    float64
#  20  symmetry_se              569 non-null    float64
#  21  fractal_dimension_se     569 non-null    float64
#  22  radius_worst             569 non-null    float64
#  23  texture_worst            569 non-null    float64
#  24  perimeter_worst          569 non-null    float64
#  25  area_worst               569 non-null    float64
#  26  smoothness_worst         569 non-null    float64
#  27  compactness_worst        569 non-null    float64
#  28  concavity_worst          569 non-null    float64
#  29  concave points_worst     569 non-null    float64
#  30  symmetry_worst           569 non-null    float64
#  31  fractal_dimension_worst  569 non-null    float64
#  32  Unnamed: 32              0 non-null      float64
# dtypes: float64(31), int64(1), object(1)
# memory usage: 146.8+ KB

# %%
df = df.drop(['id','Unnamed: 32'], axis = 'columns')

# %%
df
# Out:
#     diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0           M        17.99         10.38          122.80     1001.0
# 1           M        20.57         17.77          132.90     1326.0
# 2           M        19.69         21.25          130.00     1203.0
# 3           M        11.42         20.38           77.58      386.1
# 4           M        20.29         14.34          135.10     1297.0
# ..        ...          ...           ...             ...        ...
# 564         M        21.56         22.39          142.00     1479.0
# 565         M        20.13         28.25          131.20     1261.0
# 566         M        16.60         28.08          108.30      858.1
# 567         M        20.60         29.33          140.10     1265.0
# 568         B         7.76         24.54           47.92      181.0
#
#      smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0            0.11840           0.27760         0.30010              0.14710
# 1            0.08474           0.07864         0.08690              0.07017
# 2            0.10960           0.15990         0.19740              0.12790
# 3            0.14250           0.28390         0.24140              0.10520
# 4            0.10030           0.13280         0.19800              0.10430
# ..               ...               ...             ...                  ...
# 564          0.11100           0.11590         0.24390              0.13890
# 565          0.09780           0.10340         0.14400              0.09791
# 566          0.08455           0.10230         0.09251              0.05302
# 567          0.11780           0.27700         0.35140              0.15200
# 568          0.05263           0.04362         0.00000              0.00000
#
#      symmetry_mean  ...  radius_worst  texture_worst  perimeter_worst  \
# 0           0.2419  ...        25.380          17.33           184.60
# 1           0.1812  ...        24.990          23.41           158.80
# 2           0.2069  ...        23.570          25.53           152.50
# 3           0.2597  ...        14.910          26.50            98.87
# 4           0.1809  ...        22.540          16.67           152.20
# ..             ...  ...           ...            ...              ...
# 564         0.1726  ...        25.450          26.40           166.10
# 565         0.1752  ...        23.690          38.25           155.00
# 566         0.1590  ...        18.980          34.12           126.70
# 567         0.2397  ...        25.740          39.42           184.60
# 568         0.1587  ...         9.456          30.37            59.16
#
#      area_worst  smoothness_worst  compactness_worst  concavity_worst  \
# 0        2019.0           0.16220            0.66560           0.7119
# 1        1956.0           0.12380            0.18660           0.2416
# 2        1709.0           0.14440            0.42450           0.4504
# 3         567.7           0.20980            0.86630           0.6869
# 4        1575.0           0.13740            0.20500           0.4000
# ..          ...               ...                ...              ...
# 564      2027.0           0.14100            0.21130           0.4107
# 565      1731.0           0.11660            0.19220           0.3215
# 566      1124.0           0.11390            0.30940           0.3403
# 567      1821.0           0.16500            0.86810           0.9387
# 568       268.6           0.08996            0.06444           0.0000
#
#      concave points_worst  symmetry_worst  fractal_dimension_worst
# 0                  0.2654          0.4601                  0.11890
# 1                  0.1860          0.2750                  0.08902
# 2                  0.2430          0.3613                  0.08758
# 3                  0.2575          0.6638                  0.17300
# 4                  0.1625          0.2364                  0.07678
# ..                    ...             ...                      ...
# 564                0.2216          0.2060                  0.07115
# 565                0.1628          0.2572                  0.06637
# 566                0.1418          0.2218                  0.07820
# 567                0.2650          0.4087                  0.12400
# 568                0.0000          0.2871                  0.07039
#
# [569 rows x 31 columns]

# %%
sns.countplot(x='diagnosis',data=df)
# Out:
# <AxesSubplot:xlabel='diagnosis', ylabel='count'>

# %%
df.diagnosis.value_counts()
# Out:
# B    357
# M    212
# Name: diagnosis, dtype: int64

# %%
# Create the countplot
plt.figure(figsize=(8, 6))
ax = sns.countplot(x='diagnosis', data=df, palette='Set2')

# Annotate the bars with their respective counts
for p in ax.patches:
    height = p.get_height()
    ax.annotate(f'{height}', (p.get_x() + p.get_width() / 2, height), ha='center', va='bottom', fontsize=12)

# Optionally, you can set the y-axis label
plt.ylabel('Count')

# Show the plot
plt.show()

# %%
x = df.drop('diagnosis',axis=1)

# %%
y = df[['diagnosis']]

# %% [markdown]
# # Train Test Split

# %%
from sklearn.model_selection import train_test_split
xtrain, xtest, ytrain, ytest = train_test_split(x, y, random_state=42, test_size=.30)

# %%
ytest
# Out:
#     diagnosis
# 204         B
# 70          M
# 131         M
# 431         B
# 540         B
# ..        ...
# 69          B
# 542         B
# 176         B
# 501         M
# 247         B
#
# [171 rows x 1 columns]

# %%
ytest.shape
# Out:
# (171, 1)

# %%
xtest.shape
# Out:
# (171, 30)

# %% [markdown]
# # Test and Validation

# %%
x_test, x_val, y_test, y_val = train_test_split(xtest, ytest, random_state=42, test_size=.50)
x_test.shape #15% of total data
# Out:
# (85, 30)

# %%
x_val.shape #15% of total data ; for hyper param tuning
# Out:
# (86, 30)

# %% [markdown]
# # Step 3: Decision Tree model and evaluation

# %%
dt_model = DecisionTreeClassifier(random_state=1)
dt_model.fit(xtrain, ytrain)
y_pred_dt = dt_model.predict(xtest)

# %%
y_pred_dt
# Out:
# array(['B', 'M', 'M', 'B', 'B', 'M', 'M', 'M', 'B', 'B', 'M', 'M', 'B',
#        'M', 'B', 'M', 'B', 'B', 'B', 'M', 'B', 'B', 'M', 'B', 'B', 'B',
#        'B', 'B', 'B', 'M', 'B', 'B', 'B', 'B', 'B', 'B', 'M', 'B', 'M',
#        'B', 'B', 'M', 'B', 'B', 'B', 'B', 'M', 'M', 'B', 'B', 'M', 'M',
#        'B', 'B', 'B', 'B', 'B', 'M', 'M', 'B', 'B', 'M', 'M', 'B', 'B',
#        'B', 'M', 'M', 'B', 'B', 'M', 'M', 'B', 'M', 'B', 'B', 'B', 'M',
#        'B', 'B', 'M', 'B', 'B', 'M', 'M', 'M', 'M', 'M', 'B', 'B', 'B',
#        'B', 'M', 'B', 'B', 'B', 'M', 'M', 'B', 'M', 'M', 'B', 'M', 'M',
#        'B', 'B', 'B', 'M', 'B', 'B', 'M', 'B', 'B', 'M', 'B', 'M', 'B',
#        'B', 'B', 'M', 'M', 'B', 'B', 'M', 'B', 'M', 'M', 'B', 'B', 'M',
#        'M', 'M', 'B', 'B', 'B', 'B', 'M', 'B', 'B', 'M', 'B', 'M', 'B',
#        'B', 'M', 'B', 'M', 'M', 'M', 'B', 'M', 'B', 'B', 'B', 'M', 'M',
#        'M', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B',
#        'M', 'B'], dtype=object)

# %% [markdown]
# # Evaluate Decision Tree model performance

# %%
print("Decision Tree Model Performance:")
print("Accuracy:", accuracy_score(ytest, y_pred_dt), '\n')
print("Classification Report:")
print(classification_report(ytest, y_pred_dt))
# Out:
# Decision Tree Model Performance:
# Accuracy: 0.935672514619883
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            B       0.96      0.94      0.95       108
#            M       0.89      0.94      0.91        63
#
#     accuracy                           0.94       171
#    macro avg       0.93      0.94      0.93       171
# weighted avg       0.94      0.94      0.94       171

# %% [markdown]
# # Step 4: Random Forest model and evaluation

# %%
rf_model = RandomForestClassifier(random_state=42)
rf_model.fit(xtrain, ytrain)
y_pred_rf = rf_model.predict(xtest)

# %%
y_pred_rf
# Out:
# array(['B', 'M', 'M', 'B', 'B', 'M', 'M', 'M', 'M', 'B', 'B', 'M', 'B',
#        'M', 'B', 'M', 'B', 'B', 'B', 'M', 'B', 'B', 'M', 'B', 'B', 'B',
#        'B', 'B', 'B', 'M', 'B', 'B', 'B', 'B', 'B', 'B', 'M', 'B', 'M',
#        'B', 'B', 'M', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'M', 'M',
#        'B', 'B', 'B', 'B', 'B', 'M', 'M', 'B', 'B', 'M', 'M', 'B', 'B',
#        'B', 'M', 'M', 'B', 'B', 'M', 'M', 'B', 'M', 'B', 'B', 'B', 'B',
#        'B', 'B', 'M', 'B', 'B', 'M', 'M', 'M', 'M', 'M', 'B', 'B', 'B',
#        'B', 'B', 'B', 'B', 'B', 'M', 'M', 'B', 'M', 'M', 'B', 'M', 'M',
#        'B', 'B', 'B', 'M', 'B', 'B', 'M', 'B', 'B', 'M', 'B', 'M', 'B',
#        'B', 'B', 'M', 'B', 'B', 'B', 'M', 'B', 'M', 'M', 'B', 'B', 'M',
#        'M', 'M', 'B', 'B', 'B', 'M', 'B', 'B', 'B', 'M', 'B', 'M', 'B',
#        'B', 'M', 'B', 'M', 'M', 'M', 'B', 'M', 'B', 'B', 'B', 'B', 'M',
#        'M', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B',
#        'M', 'B'], dtype=object)

# %% [markdown]
# # Evaluate Random Forest model performance

# %%
print("\nRandom Forest Model Performance:") 
print("Accuracy:", accuracy_score(ytest, y_pred_rf), '\n') 
print("Classification Report:") 
print(classification_report(ytest, y_pred_rf))
# Out:
# Random Forest Model Performance:
# Accuracy: 0.9707602339181286
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            B       0.96      0.99      0.98       108
#            M       0.98      0.94      0.96        63
#
#     accuracy                           0.97       171
#    macro avg       0.97      0.96      0.97       171
# weighted avg       0.97      0.97      0.97       171

# %% [markdown]
# # Pre - Pruning for Cost Complexity

# %% [markdown]
# # Initialized Hyperparameters

# %%
# Define hyperparameters for Decision Tree 
dt_params = {
    'criterion': ['gini', 'entropy'],
    'splitter': ['best', 'random'],
    'max_depth': [None, 2,4,6,8,10,12, 15,20,25,28],
    'min_samples_split': [2,3,4,5,6,7,8,9,10],
    'min_samples_leaf': [1,2,3,4,5]
}


#Define hyperparameters for Random Forest
rf_params = {
    'n_estimators': [101, 151, 201, 251, 301],
    'criterion': ['gini', 'entropy'],
    'max_depth': [None, 2,4,6,8,10,15,20,25,28],
    'min_samples_split': [2,3,4,5,6,7,810],
    'min_samples_leaf': [1, 2, 3, 4],
    'max_features': ['auto', 'sqrt', 'log2']
}

# %%
# Perform Grid Search for Decision Tree
dt_grid_search = GridSearchCV(estimator = DecisionTreeClassifier(random_state=42),
                              param_grid = dt_params, cv=5)
dt_grid_search.fit(xtrain, ytrain)
# Out:
# GridSearchCV(cv=5, estimator=DecisionTreeClassifier(random_state=42),
#              param_grid={'criterion': ['gini', 'entropy'],
#                          'max_depth': [None, 2, 4, 6, 8, 10, 12, 15, 20, 25,
#                                        28],
#                          'min_samples_leaf': [1, 2, 3, 4, 5],
#                          'min_samples_split': [2, 3, 4, 5, 6, 7, 8, 9, 10],
#                          'splitter': ['best', 'random']})

# %%
dt_grid_search.cv_results_
# Out:
# {'mean_fit_time': array([0.00737796, 0.00232687, 0.00727015, ..., 0.00233984, 0.00674486,
#         0.00205488]),
#  'std_fit_time': array([0.00086743, 0.00037113, 0.00050477, ..., 0.00071817, 0.00067538,
#         0.00070358]),
#  'mean_score_time': array([0.00295997, 0.00181251, 0.00238075, ..., 0.00206141, 0.00234179,
#         0.0021275 ]),
#  'std_score_time': array([0.00050689, 0.00068877, 0.00052636, ..., 0.000277  , 0.00067922,
#         0.00020129]),
#  'param_criterion': masked_array(data=['gini', 'gini', 'gini', ..., 'entropy', 'entropy',
#                     'entropy'],
#               mask=[False, False, False, ..., False, False, False],
#         fill_value='?',
#              dtype=object),
#  'param_max_depth': masked_array(data=[None, None, None, ..., 28, 28, 28],
#               mask=[False, False, False, ..., False, False, False],
#         fill_value='?',
#              dtype=object),
#  'param_min_samples_leaf': masked_array(data=[1, 1, 1, ..., 5, 5, 5],
#               mask=[False, False, False, ..., False, False, False],
#         fill_value='?',
#              dtype=object),
#  'param_min_samples_split': masked_array(data=[2, 2, 3, ..., 9, 10, 10],
#               mask=[False, False, False, ..., False, False, False],
#         fill_value='?',
#              dtype=object),
#  'param_splitter': masked_array(data=['best', 'random', 'best', ..., 'random', 'best',
#                     'random'],
#               mask=[False, False, False, ..., False, False, False],
#         fill_value='?',
#              dtype=object),
#  'params': [{'criterion': 'gini',
#    'max_depth': None,
#    'min_samples_leaf': 1,
#    'min_samples_split': 2,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'min_samples_leaf': 1,
#    'min_samples_split': 2,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'min_samples_leaf': 1,
#    'min_samples_split': 3,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'min_samples_leaf': 1,
#    'min_samples_split': 3,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'min_samples_leaf': 1,
#    'min_samples_split': 4,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'min_samples_leaf': 1,
#    'min_samples_split': 4,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'min_samples_leaf': 1,
#    'min_samples_split': 5,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'min_samples_leaf': 1,
#    'min_samples_split': 5,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'min_samples_leaf': 1,
#    'min_samples_split': 6,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'min_samples_leaf': 1,
#    'min_samples_split': 6,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'min_samples_leaf': 1,
#    'min_samples_split': 7,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'min_samples_leaf': 1,
#    'min_samples_split': 7,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'min_samples_leaf': 1,
#    'min_samples_split': 8,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'min_samples_leaf': 1,
#    'min_samples_split': 8,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'min_samples_leaf': 1,
#    'min_samples_split': 9,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'min_samples_leaf': 1,
#    'min_samples_split': 9,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'min_samples_leaf': 1,
#    'min_samples_split': 10,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'min_samples_leaf': 1,
#    'min_samples_split': 10,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'min_samples_leaf': 2,
#    'min_samples_split': 2,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'min_samples_leaf': 2,
#    'min_samples_split': 2,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'min_samples_leaf': 2,
#    'min_samples_split': 3,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'min_samples_leaf': 2,
#    'min_samples_split': 3,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'min_samples_leaf': 2,
#    'min_samples_split': 4,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'min_samples_leaf': 2,
#    'min_samples_split': 4,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'min_samples_leaf': 2,
#    'min_samples_split': 5,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'min_samples_leaf': 2,
#    'min_samples_split': 5,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'min_samples_leaf': 2,
#    'min_samples_split': 6,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'min_samples_leaf': 2,
#    'min_samples_split': 6,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'min_samples_leaf': 2,
#    'min_samples_split': 7,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'min_samples_leaf': 2,
#    'min_samples_split': 7,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'min_samples_leaf': 2,
#    'min_samples_split': 8,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'min_samples_leaf': 2,
#    'min_samples_split': 8,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'min_samples_leaf': 2,
#    'min_samples_split': 9,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'min_samples_leaf': 2,
#    'min_samples_split': 9,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'min_samples_leaf': 2,
#    'min_samples_split': 10,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'min_samples_leaf': 2,
#    'min_samples_split': 10,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'min_samples_leaf': 3,
#    'min_samples_split': 2,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'min_samples_leaf': 3,
#    'min_samples_split': 2,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'min_samples_leaf': 3,
#    'min_samples_split': 3,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'min_samples_leaf': 3,
#    'min_samples_split': 3,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'min_samples_leaf': 3,
#    'min_samples_split': 4,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'min_samples_leaf': 3,
#    'min_samples_split': 4,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'min_samples_leaf': 3,
#    'min_samples_split': 5,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'min_samples_leaf': 3,
#    'min_samples_split': 5,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'min_samples_leaf': 3,
#    'min_samples_split': 6,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'min_samples_leaf': 3,
#    'min_samples_split': 6,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'min_samples_leaf': 3,
#    'min_samples_split': 7,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'min_samples_leaf': 3,
#    'min_samples_split': 7,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'min_samples_leaf': 3,
#    'min_samples_split': 8,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'min_samples_leaf': 3,
#    'min_samples_split': 8,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'min_samples_leaf': 3,
#    'min_samples_split': 9,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'min_samples_leaf': 3,
#    'min_samples_split': 9,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'min_samples_leaf': 3,
#    'min_samples_split': 10,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'min_samples_leaf': 3,
#    'min_samples_split': 10,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'min_samples_leaf': 4,
#    'min_samples_split': 2,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'min_samples_leaf': 4,
#    'min_samples_split': 2,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'min_samples_leaf': 4,
#    'min_samples_split': 3,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'min_samples_leaf': 4,
#    'min_samples_split': 3,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'min_samples_leaf': 4,
#    'min_samples_split': 4,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'min_samples_leaf': 4,
#    'min_samples_split': 4,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'min_samples_leaf': 4,
#    'min_samples_split': 5,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'min_samples_leaf': 4,
#    'min_samples_split': 5,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'min_samples_leaf': 4,
#    'min_samples_split': 6,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'min_samples_leaf': 4,
#    'min_samples_split': 6,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'min_samples_leaf': 4,
#    'min_samples_split': 7,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'min_samples_leaf': 4,
#    'min_samples_split': 7,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'min_samples_leaf': 4,
#    'min_samples_split': 8,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'min_samples_leaf': 4,
#    'min_samples_split': 8,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'min_samples_leaf': 4,
#    'min_samples_split': 9,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'min_samples_leaf': 4,
#    'min_samples_split': 9,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'min_samples_leaf': 4,
#    'min_samples_split': 10,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'min_samples_leaf': 4,
#    'min_samples_split': 10,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'min_samples_leaf': 5,
#    'min_samples_split': 2,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'min_samples_leaf': 5,
#    'min_samples_split': 2,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'min_samples_leaf': 5,
#    'min_samples_split': 3,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'min_samples_leaf': 5,
#    'min_samples_split': 3,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'min_samples_leaf': 5,
#    'min_samples_split': 4,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'min_samples_leaf': 5,
#    'min_samples_split': 4,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'min_samples_leaf': 5,
#    'min_samples_split': 5,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'min_samples_leaf': 5,
#    'min_samples_split': 5,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'min_samples_leaf': 5,
#    'min_samples_split': 6,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'min_samples_leaf': 5,
#    'min_samples_split': 6,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'min_samples_leaf': 5,
#    'min_samples_split': 7,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'min_samples_leaf': 5,
#    'min_samples_split': 7,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'min_samples_leaf': 5,
#    'min_samples_split': 8,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'min_samples_leaf': 5,
#    'min_samples_split': 8,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'min_samples_leaf': 5,
#    'min_samples_split': 9,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'min_samples_leaf': 5,
#    'min_samples_split': 9,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'min_samples_leaf': 5,
#    'min_samples_split': 10,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'min_samples_leaf': 5,
#    'min_samples_split': 10,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': 2,
#    'min_samples_leaf': 1,
#    'min_samples_split': 2,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': 2,
#    'min_samples_leaf': 1,
#    'min_samples_split': 2,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': 2,
#    'min_samples_leaf': 1,
#    'min_samples_split': 3,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': 2,
#    'min_samples_leaf': 1,
#    'min_samples_split': 3,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': 2,
#    'min_samples_leaf': 1,
#    'min_samples_split': 4,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': 2,
#    'min_samples_leaf': 1,
#    'min_samples_split': 4,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': 2,
#    'min_samples_leaf': 1,
#    'min_samples_split': 5,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': 2,
#    'min_samples_leaf': 1,
#    'min_samples_split': 5,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': 2,
#    'min_samples_leaf': 1,
#    'min_samples_split': 6,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': 2,
#    'min_samples_leaf': 1,
#    'min_samples_split': 6,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': 2,
#    'min_samples_leaf': 1,
#    'min_samples_split': 7,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': 2,
#    'min_samples_leaf': 1,
#    'min_samples_split': 7,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': 2,
#    'min_samples_leaf': 1,
#    'min_samples_split': 8,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': 2,
#    'min_samples_leaf': 1,
#    'min_samples_split': 8,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': 2,
#    'min_samples_leaf': 1,
#    'min_samples_split': 9,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': 2,
#    'min_samples_leaf': 1,
#    'min_samples_split': 9,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': 2,
#    'min_samples_leaf': 1,
#    'min_samples_split': 10,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': 2,
#    'min_samples_leaf': 1,
#    'min_samples_split': 10,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': 2,
#    'min_samples_leaf': 2,
#    'min_samples_split': 2,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': 2,
#    'min_samples_leaf': 2,
#    'min_samples_split': 2,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': 2,
#    'min_samples_leaf': 2,
#    'min_samples_split': 3,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': 2,
#    'min_samples_leaf': 2,
#    'min_samples_split': 3,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': 2,
#    'min_samples_leaf': 2,
#    'min_samples_split': 4,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': 2,
#    'min_samples_leaf': 2,
#    'min_samples_split': 4,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': 2,
#    'min_samples_leaf': 2,
#    'min_samples_split': 5,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': 2,
#    'min_samples_leaf': 2,
#    'min_samples_split': 5,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': 2,
#    'min_samples_leaf': 2,
#    'min_samples_split': 6,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': 2,
#    'min_samples_leaf': 2,
#    'min_samples_split': 6,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': 2,
#    'min_samples_leaf': 2,
#    'min_samples_split': 7,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': 2,
#    'min_samples_leaf': 2,
#    'min_samples_split': 7,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': 2,
#    'min_samples_leaf': 2,
#    'min_samples_split': 8,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': 2,
#    'min_samples_leaf': 2,
#    'min_samples_split': 8,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': 2,
#    'min_samples_leaf': 2,
#    'min_samples_split': 9,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': 2,
#    'min_samples_leaf': 2,
#    'min_samples_split': 9,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': 2,
#    'min_samples_leaf': 2,
#    'min_samples_split': 10,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': 2,
#    'min_samples_leaf': 2,
#    'min_samples_split': 10,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': 2,
#    'min_samples_leaf': 3,
#    'min_samples_split': 2,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': 2,
#    'min_samples_leaf': 3,
#    'min_samples_split': 2,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': 2,
#    'min_samples_leaf': 3,
#    'min_samples_split': 3,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': 2,
#    'min_samples_leaf': 3,
#    'min_samples_split': 3,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': 2,
#    'min_samples_leaf': 3,
#    'min_samples_split': 4,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': 2,
#    'min_samples_leaf': 3,
#    'min_samples_split': 4,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': 2,
#    'min_samples_leaf': 3,
#    'min_samples_split': 5,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': 2,
#    'min_samples_leaf': 3,
#    'min_samples_split': 5,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': 2,
#    'min_samples_leaf': 3,
#    'min_samples_split': 6,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': 2,
#    'min_samples_leaf': 3,
#    'min_samples_split': 6,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': 2,
#    'min_samples_leaf': 3,
#    'min_samples_split': 7,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': 2,
#    'min_samples_leaf': 3,
#    'min_samples_split': 7,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': 2,
#    'min_samples_leaf': 3,
#    'min_samples_split': 8,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': 2,
#    'min_samples_leaf': 3,
#    'min_samples_split': 8,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': 2,
#    'min_samples_leaf': 3,
#    'min_samples_split': 9,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': 2,
#    'min_samples_leaf': 3,
#    'min_samples_split': 9,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': 2,
#    'min_samples_leaf': 3,
#    'min_samples_split': 10,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': 2,
#    'min_samples_leaf': 3,
#    'min_samples_split': 10,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': 2,
#    'min_samples_leaf': 4,
#    'min_samples_split': 2,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': 2,
#    'min_samples_leaf': 4,
#    'min_samples_split': 2,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': 2,
#    'min_samples_leaf': 4,
#    'min_samples_split': 3,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': 2,
#    'min_samples_leaf': 4,
#    'min_samples_split': 3,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': 2,
#    'min_samples_leaf': 4,
#    'min_samples_split': 4,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': 2,
#    'min_samples_leaf': 4,
#    'min_samples_split': 4,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': 2,
#    'min_samples_leaf': 4,
#    'min_samples_split': 5,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': 2,
#    'min_samples_leaf': 4,
#    'min_samples_split': 5,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': 2,
#    'min_samples_leaf': 4,
#    'min_samples_split': 6,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': 2,
#    'min_samples_leaf': 4,
#    'min_samples_split': 6,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': 2,
#    'min_samples_leaf': 4,
#    'min_samples_split': 7,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': 2,
#    'min_samples_leaf': 4,
#    'min_samples_split': 7,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': 2,
#    'min_samples_leaf': 4,
#    'min_samples_split': 8,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': 2,
#    'min_samples_leaf': 4,
#    'min_samples_split': 8,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': 2,
#    'min_samples_leaf': 4,
#    'min_samples_split': 9,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': 2,
#    'min_samples_leaf': 4,
#    'min_samples_split': 9,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': 2,
#    'min_samples_leaf': 4,
#    'min_samples_split': 10,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': 2,
#    'min_samples_leaf': 4,
#    'min_samples_split': 10,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': 2,
#    'min_samples_leaf': 5,
#    'min_samples_split': 2,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': 2,
#    'min_samples_leaf': 5,
#    'min_samples_split': 2,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': 2,
#    'min_samples_leaf': 5,
#    'min_samples_split': 3,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': 2,
#    'min_samples_leaf': 5,
#    'min_samples_split': 3,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': 2,
#    'min_samples_leaf': 5,
#    'min_samples_split': 4,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': 2,
#    'min_samples_leaf': 5,
#    'min_samples_split': 4,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': 2,
#    'min_samples_leaf': 5,
#    'min_samples_split': 5,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': 2,
#    'min_samples_leaf': 5,
#    'min_samples_split': 5,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': 2,
#    'min_samples_leaf': 5,
#    'min_samples_split': 6,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': 2,
#    'min_samples_leaf': 5,
#    'min_samples_split': 6,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': 2,
#    'min_samples_leaf': 5,
#    'min_samples_split': 7,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': 2,
#    'min_samples_leaf': 5,
#    'min_samples_split': 7,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': 2,
#    'min_samples_leaf': 5,
#    'min_samples_split': 8,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': 2,
#    'min_samples_leaf': 5,
#    'min_samples_split': 8,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': 2,
#    'min_samples_leaf': 5,
#    'min_samples_split': 9,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': 2,
#    'min_samples_leaf': 5,
#    'min_samples_split': 9,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': 2,
#    'min_samples_leaf': 5,
#    'min_samples_split': 10,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': 2,
#    'min_samples_leaf': 5,
#    'min_samples_split': 10,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': 4,
#    'min_samples_leaf': 1,
#    'min_samples_split': 2,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': 4,
#    'min_samples_leaf': 1,
#    'min_samples_split': 2,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': 4,
#    'min_samples_leaf': 1,
#    'min_samples_split': 3,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': 4,
#    'min_samples_leaf': 1,
#    'min_samples_split': 3,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': 4,
#    'min_samples_leaf': 1,
#    'min_samples_split': 4,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': 4,
#    'min_samples_leaf': 1,
#    'min_samples_split': 4,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': 4,
#    'min_samples_leaf': 1,
#    'min_samples_split': 5,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': 4,
#    'min_samples_leaf': 1,
#    'min_samples_split': 5,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': 4,
#    'min_samples_leaf': 1,
#    'min_samples_split': 6,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': 4,
#    'min_samples_leaf': 1,
#    'min_samples_split': 6,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': 4,
#    'min_samples_leaf': 1,
#    'min_samples_split': 7,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': 4,
#    'min_samples_leaf': 1,
#    'min_samples_split': 7,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': 4,
#    'min_samples_leaf': 1,
#    'min_samples_split': 8,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': 4,
#    'min_samples_leaf': 1,
#    'min_samples_split': 8,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': 4,
#    'min_samples_leaf': 1,
#    'min_samples_split': 9,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': 4,
#    'min_samples_leaf': 1,
#    'min_samples_split': 9,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': 4,
#    'min_samples_leaf': 1,
#    'min_samples_split': 10,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': 4,
#    'min_samples_leaf': 1,
#    'min_samples_split': 10,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': 4,
#    'min_samples_leaf': 2,
#    'min_samples_split': 2,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': 4,
#    'min_samples_leaf': 2,
#    'min_samples_split': 2,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': 4,
#    'min_samples_leaf': 2,
#    'min_samples_split': 3,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': 4,
#    'min_samples_leaf': 2,
#    'min_samples_split': 3,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': 4,
#    'min_samples_leaf': 2,
#    'min_samples_split': 4,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': 4,
#    'min_samples_leaf': 2,
#    'min_samples_split': 4,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': 4,
#    'min_samples_leaf': 2,
#    'min_samples_split': 5,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': 4,
#    'min_samples_leaf': 2,
#    'min_samples_split': 5,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': 4,
#    'min_samples_leaf': 2,
#    'min_samples_split': 6,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': 4,
#    'min_samples_leaf': 2,
#    'min_samples_split': 6,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': 4,
#    'min_samples_leaf': 2,
#    'min_samples_split': 7,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': 4,
#    'min_samples_leaf': 2,
#    'min_samples_split': 7,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': 4,
#    'min_samples_leaf': 2,
#    'min_samples_split': 8,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': 4,
#    'min_samples_leaf': 2,
#    'min_samples_split': 8,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': 4,
#    'min_samples_leaf': 2,
#    'min_samples_split': 9,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': 4,
#    'min_samples_leaf': 2,
#    'min_samples_split': 9,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': 4,
#    'min_samples_leaf': 2,
#    'min_samples_split': 10,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': 4,
#    'min_samples_leaf': 2,
#    'min_samples_split': 10,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': 4,
#    'min_samples_leaf': 3,
#    'min_samples_split': 2,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': 4,
#    'min_samples_leaf': 3,
#    'min_samples_split': 2,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': 4,
#    'min_samples_leaf': 3,
#    'min_samples_split': 3,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': 4,
#    'min_samples_leaf': 3,
#    'min_samples_split': 3,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': 4,
#    'min_samples_leaf': 3,
#    'min_samples_split': 4,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': 4,
#    'min_samples_leaf': 3,
#    'min_samples_split': 4,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': 4,
#    'min_samples_leaf': 3,
#    'min_samples_split': 5,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': 4,
#    'min_samples_leaf': 3,
#    'min_samples_split': 5,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': 4,
#    'min_samples_leaf': 3,
#    'min_samples_split': 6,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': 4,
#    'min_samples_leaf': 3,
#    'min_samples_split': 6,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': 4,
#    'min_samples_leaf': 3,
#    'min_samples_split': 7,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': 4,
#    'min_samples_leaf': 3,
#    'min_samples_split': 7,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': 4,
#    'min_samples_leaf': 3,
#    'min_samples_split': 8,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': 4,
#    'min_samples_leaf': 3,
#    'min_samples_split': 8,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': 4,
#    'min_samples_leaf': 3,
#    'min_samples_split': 9,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': 4,
#    'min_samples_leaf': 3,
#    'min_samples_split': 9,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': 4,
#    'min_samples_leaf': 3,
#    'min_samples_split': 10,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': 4,
#    'min_samples_leaf': 3,
#    'min_samples_split': 10,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': 4,
#    'min_samples_leaf': 4,
#    'min_samples_split': 2,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': 4,
#    'min_samples_leaf': 4,
#    'min_samples_split': 2,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': 4,
#    'min_samples_leaf': 4,
#    'min_samples_split': 3,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': 4,
#    'min_samples_leaf': 4,
#    'min_samples_split': 3,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': 4,
#    'min_samples_leaf': 4,
#    'min_samples_split': 4,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': 4,
#    'min_samples_leaf': 4,
#    'min_samples_split': 4,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': 4,
#    'min_samples_leaf': 4,
#    'min_samples_split': 5,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': 4,
#    'min_samples_leaf': 4,
#    'min_samples_split': 5,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': 4,
#    'min_samples_leaf': 4,
#    'min_samples_split': 6,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': 4,
#    'min_samples_leaf': 4,
#    'min_samples_split': 6,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': 4,
#    'min_samples_leaf': 4,
#    'min_samples_split': 7,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': 4,
#    'min_samples_leaf': 4,
#    'min_samples_split': 7,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': 4,
#    'min_samples_leaf': 4,
#    'min_samples_split': 8,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': 4,
#    'min_samples_leaf': 4,
#    'min_samples_split': 8,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': 4,
#    'min_samples_leaf': 4,
#    'min_samples_split': 9,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': 4,
#    'min_samples_leaf': 4,
#    'min_samples_split': 9,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': 4,
#    'min_samples_leaf': 4,
#    'min_samples_split': 10,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': 4,
#    'min_samples_leaf': 4,
#    'min_samples_split': 10,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': 4,
#    'min_samples_leaf': 5,
#    'min_samples_split': 2,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': 4,
#    'min_samples_leaf': 5,
#    'min_samples_split': 2,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': 4,
#    'min_samples_leaf': 5,
#    'min_samples_split': 3,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': 4,
#    'min_samples_leaf': 5,
#    'min_samples_split': 3,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': 4,
#    'min_samples_leaf': 5,
#    'min_samples_split': 4,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': 4,
#    'min_samples_leaf': 5,
#    'min_samples_split': 4,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': 4,
#    'min_samples_leaf': 5,
#    'min_samples_split': 5,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': 4,
#    'min_samples_leaf': 5,
#    'min_samples_split': 5,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': 4,
#    'min_samples_leaf': 5,
#    'min_samples_split': 6,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': 4,
#    'min_samples_leaf': 5,
#    'min_samples_split': 6,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': 4,
#    'min_samples_leaf': 5,
#    'min_samples_split': 7,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': 4,
#    'min_samples_leaf': 5,
#    'min_samples_split': 7,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': 4,
#    'min_samples_leaf': 5,
#    'min_samples_split': 8,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': 4,
#    'min_samples_leaf': 5,
#    'min_samples_split': 8,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': 4,
#    'min_samples_leaf': 5,
#    'min_samples_split': 9,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': 4,
#    'min_samples_leaf': 5,
#    'min_samples_split': 9,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': 4,
#    'min_samples_leaf': 5,
#    'min_samples_split': 10,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': 4,
#    'min_samples_leaf': 5,
#    'min_samples_split': 10,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': 6,
#    'min_samples_leaf': 1,
#    'min_samples_split': 2,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': 6,
#    'min_samples_leaf': 1,
#    'min_samples_split': 2,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': 6,
#    'min_samples_leaf': 1,
#    'min_samples_split': 3,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': 6,
#    'min_samples_leaf': 1,
#    'min_samples_split': 3,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': 6,
#    'min_samples_leaf': 1,
#    'min_samples_split': 4,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': 6,
#    'min_samples_leaf': 1,
#    'min_samples_split': 4,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': 6,
#    'min_samples_leaf': 1,
#    'min_samples_split': 5,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': 6,
#    'min_samples_leaf': 1,
#    'min_samples_split': 5,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': 6,
#    'min_samples_leaf': 1,
#    'min_samples_split': 6,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': 6,
#    'min_samples_leaf': 1,
#    'min_samples_split': 6,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': 6,
#    'min_samples_leaf': 1,
#    'min_samples_split': 7,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': 6,
#    'min_samples_leaf': 1,
#    'min_samples_split': 7,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': 6,
#    'min_samples_leaf': 1,
#    'min_samples_split': 8,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': 6,
#    'min_samples_leaf': 1,
#    'min_samples_split': 8,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': 6,
#    'min_samples_leaf': 1,
#    'min_samples_split': 9,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': 6,
#    'min_samples_leaf': 1,
#    'min_samples_split': 9,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': 6,
#    'min_samples_leaf': 1,
#    'min_samples_split': 10,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': 6,
#    'min_samples_leaf': 1,
#    'min_samples_split': 10,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': 6,
#    'min_samples_leaf': 2,
#    'min_samples_split': 2,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': 6,
#    'min_samples_leaf': 2,
#    'min_samples_split': 2,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': 6,
#    'min_samples_leaf': 2,
#    'min_samples_split': 3,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': 6,
#    'min_samples_leaf': 2,
#    'min_samples_split': 3,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': 6,
#    'min_samples_leaf': 2,
#    'min_samples_split': 4,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': 6,
#    'min_samples_leaf': 2,
#    'min_samples_split': 4,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': 6,
#    'min_samples_leaf': 2,
#    'min_samples_split': 5,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': 6,
#    'min_samples_leaf': 2,
#    'min_samples_split': 5,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': 6,
#    'min_samples_leaf': 2,
#    'min_samples_split': 6,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': 6,
#    'min_samples_leaf': 2,
#    'min_samples_split': 6,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': 6,
#    'min_samples_leaf': 2,
#    'min_samples_split': 7,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': 6,
#    'min_samples_leaf': 2,
#    'min_samples_split': 7,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': 6,
#    'min_samples_leaf': 2,
#    'min_samples_split': 8,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': 6,
#    'min_samples_leaf': 2,
#    'min_samples_split': 8,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': 6,
#    'min_samples_leaf': 2,
#    'min_samples_split': 9,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': 6,
#    'min_samples_leaf': 2,
#    'min_samples_split': 9,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': 6,
#    'min_samples_leaf': 2,
#    'min_samples_split': 10,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': 6,
#    'min_samples_leaf': 2,
#    'min_samples_split': 10,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': 6,
#    'min_samples_leaf': 3,
#    'min_samples_split': 2,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': 6,
#    'min_samples_leaf': 3,
#    'min_samples_split': 2,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': 6,
#    'min_samples_leaf': 3,
#    'min_samples_split': 3,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': 6,
#    'min_samples_leaf': 3,
#    'min_samples_split': 3,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': 6,
#    'min_samples_leaf': 3,
#    'min_samples_split': 4,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': 6,
#    'min_samples_leaf': 3,
#    'min_samples_split': 4,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': 6,
#    'min_samples_leaf': 3,
#    'min_samples_split': 5,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': 6,
#    'min_samples_leaf': 3,
#    'min_samples_split': 5,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': 6,
#    'min_samples_leaf': 3,
#    'min_samples_split': 6,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': 6,
#    'min_samples_leaf': 3,
#    'min_samples_split': 6,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': 6,
#    'min_samples_leaf': 3,
#    'min_samples_split': 7,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': 6,
#    'min_samples_leaf': 3,
#    'min_samples_split': 7,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': 6,
#    'min_samples_leaf': 3,
#    'min_samples_split': 8,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': 6,
#    'min_samples_leaf': 3,
#    'min_samples_split': 8,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': 6,
#    'min_samples_leaf': 3,
#    'min_samples_split': 9,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': 6,
#    'min_samples_leaf': 3,
#    'min_samples_split': 9,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': 6,
#    'min_samples_leaf': 3,
#    'min_samples_split': 10,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': 6,
#    'min_samples_leaf': 3,
#    'min_samples_split': 10,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': 6,
#    'min_samples_leaf': 4,
#    'min_samples_split': 2,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': 6,
#    'min_samples_leaf': 4,
#    'min_samples_split': 2,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': 6,
#    'min_samples_leaf': 4,
#    'min_samples_split': 3,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': 6,
#    'min_samples_leaf': 4,
#    'min_samples_split': 3,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': 6,
#    'min_samples_leaf': 4,
#    'min_samples_split': 4,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': 6,
#    'min_samples_leaf': 4,
#    'min_samples_split': 4,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': 6,
#    'min_samples_leaf': 4,
#    'min_samples_split': 5,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': 6,
#    'min_samples_leaf': 4,
#    'min_samples_split': 5,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': 6,
#    'min_samples_leaf': 4,
#    'min_samples_split': 6,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': 6,
#    'min_samples_leaf': 4,
#    'min_samples_split': 6,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': 6,
#    'min_samples_leaf': 4,
#    'min_samples_split': 7,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': 6,
#    'min_samples_leaf': 4,
#    'min_samples_split': 7,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': 6,
#    'min_samples_leaf': 4,
#    'min_samples_split': 8,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': 6,
#    'min_samples_leaf': 4,
#    'min_samples_split': 8,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': 6,
#    'min_samples_leaf': 4,
#    'min_samples_split': 9,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': 6,
#    'min_samples_leaf': 4,
#    'min_samples_split': 9,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': 6,
#    'min_samples_leaf': 4,
#    'min_samples_split': 10,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': 6,
#    'min_samples_leaf': 4,
#    'min_samples_split': 10,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': 6,
#    'min_samples_leaf': 5,
#    'min_samples_split': 2,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': 6,
#    'min_samples_leaf': 5,
#    'min_samples_split': 2,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': 6,
#    'min_samples_leaf': 5,
#    'min_samples_split': 3,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': 6,
#    'min_samples_leaf': 5,
#    'min_samples_split': 3,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': 6,
#    'min_samples_leaf': 5,
#    'min_samples_split': 4,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': 6,
#    'min_samples_leaf': 5,
#    'min_samples_split': 4,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': 6,
#    'min_samples_leaf': 5,
#    'min_samples_split': 5,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': 6,
#    'min_samples_leaf': 5,
#    'min_samples_split': 5,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': 6,
#    'min_samples_leaf': 5,
#    'min_samples_split': 6,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': 6,
#    'min_samples_leaf': 5,
#    'min_samples_split': 6,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': 6,
#    'min_samples_leaf': 5,
#    'min_samples_split': 7,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': 6,
#    'min_samples_leaf': 5,
#    'min_samples_split': 7,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': 6,
#    'min_samples_leaf': 5,
#    'min_samples_split': 8,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': 6,
#    'min_samples_leaf': 5,
#    'min_samples_split': 8,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': 6,
#    'min_samples_leaf': 5,
#    'min_samples_split': 9,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': 6,
#    'min_samples_leaf': 5,
#    'min_samples_split': 9,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': 6,
#    'min_samples_leaf': 5,
#    'min_samples_split': 10,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': 6,
#    'min_samples_leaf': 5,
#    'min_samples_split': 10,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': 8,
#    'min_samples_leaf': 1,
#    'min_samples_split': 2,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': 8,
#    'min_samples_leaf': 1,
#    'min_samples_split': 2,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': 8,
#    'min_samples_leaf': 1,
#    'min_samples_split': 3,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': 8,
#    'min_samples_leaf': 1,
#    'min_samples_split': 3,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': 8,
#    'min_samples_leaf': 1,
#    'min_samples_split': 4,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': 8,
#    'min_samples_leaf': 1,
#    'min_samples_split': 4,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': 8,
#    'min_samples_leaf': 1,
#    'min_samples_split': 5,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': 8,
#    'min_samples_leaf': 1,
#    'min_samples_split': 5,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': 8,
#    'min_samples_leaf': 1,
#    'min_samples_split': 6,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': 8,
#    'min_samples_leaf': 1,
#    'min_samples_split': 6,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': 8,
#    'min_samples_leaf': 1,
#    'min_samples_split': 7,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': 8,
#    'min_samples_leaf': 1,
#    'min_samples_split': 7,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': 8,
#    'min_samples_leaf': 1,
#    'min_samples_split': 8,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': 8,
#    'min_samples_leaf': 1,
#    'min_samples_split': 8,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': 8,
#    'min_samples_leaf': 1,
#    'min_samples_split': 9,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': 8,
#    'min_samples_leaf': 1,
#    'min_samples_split': 9,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': 8,
#    'min_samples_leaf': 1,
#    'min_samples_split': 10,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': 8,
#    'min_samples_leaf': 1,
#    'min_samples_split': 10,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': 8,
#    'min_samples_leaf': 2,
#    'min_samples_split': 2,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': 8,
#    'min_samples_leaf': 2,
#    'min_samples_split': 2,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': 8,
#    'min_samples_leaf': 2,
#    'min_samples_split': 3,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': 8,
#    'min_samples_leaf': 2,
# ...
#   {'criterion': 'gini',
#    'max_depth': 25,
#    'min_samples_leaf': 4,
#    'min_samples_split': 8,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': 25,
#    'min_samples_leaf': 4,
#    'min_samples_split': 8,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': 25,
#    'min_samples_leaf': 4,
#    'min_samples_split': 9,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': 25,
#    'min_samples_leaf': 4,
#    'min_samples_split': 9,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': 25,
#    'min_samples_leaf': 4,
#    'min_samples_split': 10,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': 25,
#    'min_samples_leaf': 4,
#    'min_samples_split': 10,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': 25,
#    'min_samples_leaf': 5,
#    'min_samples_split': 2,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': 25,
#    'min_samples_leaf': 5,
#    'min_samples_split': 2,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': 25,
#    'min_samples_leaf': 5,
#    'min_samples_split': 3,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': 25,
#    'min_samples_leaf': 5,
#    'min_samples_split': 3,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': 25,
#    'min_samples_leaf': 5,
#    'min_samples_split': 4,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': 25,
#    'min_samples_leaf': 5,
#    'min_samples_split': 4,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': 25,
#    'min_samples_leaf': 5,
#    'min_samples_split': 5,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': 25,
#    'min_samples_leaf': 5,
#    'min_samples_split': 5,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': 25,
#    'min_samples_leaf': 5,
#    'min_samples_split': 6,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': 25,
#    'min_samples_leaf': 5,
#    'min_samples_split': 6,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': 25,
#    'min_samples_leaf': 5,
#    'min_samples_split': 7,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': 25,
#    'min_samples_leaf': 5,
#    'min_samples_split': 7,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': 25,
#    'min_samples_leaf': 5,
#    'min_samples_split': 8,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': 25,
#    'min_samples_leaf': 5,
#    'min_samples_split': 8,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': 25,
#    'min_samples_leaf': 5,
#    'min_samples_split': 9,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': 25,
#    'min_samples_leaf': 5,
#    'min_samples_split': 9,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': 25,
#    'min_samples_leaf': 5,
#    'min_samples_split': 10,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': 25,
#    'min_samples_leaf': 5,
#    'min_samples_split': 10,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': 28,
#    'min_samples_leaf': 1,
#    'min_samples_split': 2,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': 28,
#    'min_samples_leaf': 1,
#    'min_samples_split': 2,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': 28,
#    'min_samples_leaf': 1,
#    'min_samples_split': 3,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': 28,
#    'min_samples_leaf': 1,
#    'min_samples_split': 3,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': 28,
#    'min_samples_leaf': 1,
#    'min_samples_split': 4,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': 28,
#    'min_samples_leaf': 1,
#    'min_samples_split': 4,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': 28,
#    'min_samples_leaf': 1,
#    'min_samples_split': 5,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': 28,
#    'min_samples_leaf': 1,
#    'min_samples_split': 5,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': 28,
#    'min_samples_leaf': 1,
#    'min_samples_split': 6,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': 28,
#    'min_samples_leaf': 1,
#    'min_samples_split': 6,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': 28,
#    'min_samples_leaf': 1,
#    'min_samples_split': 7,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': 28,
#    'min_samples_leaf': 1,
#    'min_samples_split': 7,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': 28,
#    'min_samples_leaf': 1,
#    'min_samples_split': 8,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': 28,
#    'min_samples_leaf': 1,
#    'min_samples_split': 8,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': 28,
#    'min_samples_leaf': 1,
#    'min_samples_split': 9,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': 28,
#    'min_samples_leaf': 1,
#    'min_samples_split': 9,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': 28,
#    'min_samples_leaf': 1,
#    'min_samples_split': 10,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': 28,
#    'min_samples_leaf': 1,
#    'min_samples_split': 10,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': 28,
#    'min_samples_leaf': 2,
#    'min_samples_split': 2,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': 28,
#    'min_samples_leaf': 2,
#    'min_samples_split': 2,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': 28,
#    'min_samples_leaf': 2,
#    'min_samples_split': 3,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': 28,
#    'min_samples_leaf': 2,
#    'min_samples_split': 3,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': 28,
#    'min_samples_leaf': 2,
#    'min_samples_split': 4,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': 28,
#    'min_samples_leaf': 2,
#    'min_samples_split': 4,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': 28,
#    'min_samples_leaf': 2,
#    'min_samples_split': 5,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': 28,
#    'min_samples_leaf': 2,
#    'min_samples_split': 5,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': 28,
#    'min_samples_leaf': 2,
#    'min_samples_split': 6,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': 28,
#    'min_samples_leaf': 2,
#    'min_samples_split': 6,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': 28,
#    'min_samples_leaf': 2,
#    'min_samples_split': 7,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': 28,
#    'min_samples_leaf': 2,
#    'min_samples_split': 7,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': 28,
#    'min_samples_leaf': 2,
#    'min_samples_split': 8,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': 28,
#    'min_samples_leaf': 2,
#    'min_samples_split': 8,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': 28,
#    'min_samples_leaf': 2,
#    'min_samples_split': 9,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': 28,
#    'min_samples_leaf': 2,
#    'min_samples_split': 9,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': 28,
#    'min_samples_leaf': 2,
#    'min_samples_split': 10,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': 28,
#    'min_samples_leaf': 2,
#    'min_samples_split': 10,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': 28,
#    'min_samples_leaf': 3,
#    'min_samples_split': 2,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': 28,
#    'min_samples_leaf': 3,
#    'min_samples_split': 2,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': 28,
#    'min_samples_leaf': 3,
#    'min_samples_split': 3,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': 28,
#    'min_samples_leaf': 3,
#    'min_samples_split': 3,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': 28,
#    'min_samples_leaf': 3,
#    'min_samples_split': 4,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': 28,
#    'min_samples_leaf': 3,
#    'min_samples_split': 4,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': 28,
#    'min_samples_leaf': 3,
#    'min_samples_split': 5,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': 28,
#    'min_samples_leaf': 3,
#    'min_samples_split': 5,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': 28,
#    'min_samples_leaf': 3,
#    'min_samples_split': 6,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': 28,
#    'min_samples_leaf': 3,
#    'min_samples_split': 6,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': 28,
#    'min_samples_leaf': 3,
#    'min_samples_split': 7,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': 28,
#    'min_samples_leaf': 3,
#    'min_samples_split': 7,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': 28,
#    'min_samples_leaf': 3,
#    'min_samples_split': 8,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': 28,
#    'min_samples_leaf': 3,
#    'min_samples_split': 8,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': 28,
#    'min_samples_leaf': 3,
#    'min_samples_split': 9,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': 28,
#    'min_samples_leaf': 3,
#    'min_samples_split': 9,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': 28,
#    'min_samples_leaf': 3,
#    'min_samples_split': 10,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': 28,
#    'min_samples_leaf': 3,
#    'min_samples_split': 10,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': 28,
#    'min_samples_leaf': 4,
#    'min_samples_split': 2,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': 28,
#    'min_samples_leaf': 4,
#    'min_samples_split': 2,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': 28,
#    'min_samples_leaf': 4,
#    'min_samples_split': 3,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': 28,
#    'min_samples_leaf': 4,
#    'min_samples_split': 3,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': 28,
#    'min_samples_leaf': 4,
#    'min_samples_split': 4,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': 28,
#    'min_samples_leaf': 4,
#    'min_samples_split': 4,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': 28,
#    'min_samples_leaf': 4,
#    'min_samples_split': 5,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': 28,
#    'min_samples_leaf': 4,
#    'min_samples_split': 5,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': 28,
#    'min_samples_leaf': 4,
#    'min_samples_split': 6,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': 28,
#    'min_samples_leaf': 4,
#    'min_samples_split': 6,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': 28,
#    'min_samples_leaf': 4,
#    'min_samples_split': 7,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': 28,
#    'min_samples_leaf': 4,
#    'min_samples_split': 7,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': 28,
#    'min_samples_leaf': 4,
#    'min_samples_split': 8,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': 28,
#    'min_samples_leaf': 4,
#    'min_samples_split': 8,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': 28,
#    'min_samples_leaf': 4,
#    'min_samples_split': 9,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': 28,
#    'min_samples_leaf': 4,
#    'min_samples_split': 9,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': 28,
#    'min_samples_leaf': 4,
#    'min_samples_split': 10,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': 28,
#    'min_samples_leaf': 4,
#    'min_samples_split': 10,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': 28,
#    'min_samples_leaf': 5,
#    'min_samples_split': 2,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': 28,
#    'min_samples_leaf': 5,
#    'min_samples_split': 2,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': 28,
#    'min_samples_leaf': 5,
#    'min_samples_split': 3,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': 28,
#    'min_samples_leaf': 5,
#    'min_samples_split': 3,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': 28,
#    'min_samples_leaf': 5,
#    'min_samples_split': 4,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': 28,
#    'min_samples_leaf': 5,
#    'min_samples_split': 4,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': 28,
#    'min_samples_leaf': 5,
#    'min_samples_split': 5,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': 28,
#    'min_samples_leaf': 5,
#    'min_samples_split': 5,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': 28,
#    'min_samples_leaf': 5,
#    'min_samples_split': 6,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': 28,
#    'min_samples_leaf': 5,
#    'min_samples_split': 6,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': 28,
#    'min_samples_leaf': 5,
#    'min_samples_split': 7,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': 28,
#    'min_samples_leaf': 5,
#    'min_samples_split': 7,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': 28,
#    'min_samples_leaf': 5,
#    'min_samples_split': 8,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': 28,
#    'min_samples_leaf': 5,
#    'min_samples_split': 8,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': 28,
#    'min_samples_leaf': 5,
#    'min_samples_split': 9,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': 28,
#    'min_samples_leaf': 5,
#    'min_samples_split': 9,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': 28,
#    'min_samples_leaf': 5,
#    'min_samples_split': 10,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': 28,
#    'min_samples_leaf': 5,
#    'min_samples_split': 10,
#    'splitter': 'random'},
#   {'criterion': 'entropy',
#    'max_depth': None,
#    'min_samples_leaf': 1,
#    'min_samples_split': 2,
#    'splitter': 'best'},
#   {'criterion': 'entropy',
#    'max_depth': None,
#    'min_samples_leaf': 1,
#    'min_samples_split': 2,
#    'splitter': 'random'},
#   {'criterion': 'entropy',
#    'max_depth': None,
#    'min_samples_leaf': 1,
#    'min_samples_split': 3,
#    'splitter': 'best'},
#   {'criterion': 'entropy',
#    'max_depth': None,
#    'min_samples_leaf': 1,
#    'min_samples_split': 3,
#    'splitter': 'random'},
#   {'criterion': 'entropy',
#    'max_depth': None,
#    'min_samples_leaf': 1,
#    'min_samples_split': 4,
#    'splitter': 'best'},
#   {'criterion': 'entropy',
#    'max_depth': None,
#    'min_samples_leaf': 1,
#    'min_samples_split': 4,
#    'splitter': 'random'},
#   {'criterion': 'entropy',
#    'max_depth': None,
#    'min_samples_leaf': 1,
#    'min_samples_split': 5,
#    'splitter': 'best'},
#   {'criterion': 'entropy',
#    'max_depth': None,
#    'min_samples_leaf': 1,
#    'min_samples_split': 5,
#    'splitter': 'random'},
#   {'criterion': 'entropy',
#    'max_depth': None,
#    'min_samples_leaf': 1,
#    'min_samples_split': 6,
#    'splitter': 'best'},
#   {'criterion': 'entropy',
#    'max_depth': None,
#    'min_samples_leaf': 1,
#    'min_samples_split': 6,
#    'splitter': 'random'},
#   ...],
#  'split0_test_score': array([0.9125, 0.9375, 0.9125, ..., 0.925 , 0.925 , 0.925 ]),
#  'split1_test_score': array([0.8875, 0.9   , 0.8875, ..., 0.875 , 0.8875, 0.875 ]),
#  'split2_test_score': array([0.9   , 0.9625, 0.9   , ..., 0.925 , 0.9625, 0.925 ]),
#  'split3_test_score': array([0.93670886, 0.91139241, 0.93670886, ..., 0.88607595, 0.94936709,
#         0.88607595]),
#  'split4_test_score': array([0.91139241, 0.94936709, 0.91139241, ..., 0.86075949, 0.92405063,
#         0.86075949]),
#  'mean_test_score': array([0.90962025, 0.9321519 , 0.90962025, ..., 0.89436709, 0.92968354,
#         0.89436709]),
#  'std_test_score': array([0.0162916 , 0.02328379, 0.0162916 , ..., 0.02626803, 0.02568065,
#         0.02626803]),
#  'rank_test_score': array([1569,  334, 1569, ..., 1847,  387, 1847])}

# %%
tuning_result_dt_gs = pd.DataFrame(dt_grid_search.cv_results_)
tuning_result_dt_gs.head()
# Out:
#    mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0       0.007378      0.000867         0.002960        0.000507
# 1       0.002327      0.000371         0.001813        0.000689
# 2       0.007270      0.000505         0.002381        0.000526
# 3       0.002557      0.000085         0.002038        0.000046
# 4       0.007146      0.000710         0.002563        0.000509
#
#   param_criterion param_max_depth param_min_samples_leaf  \
# 0            gini            None                      1
# 1            gini            None                      1
# 2            gini            None                      1
# 3            gini            None                      1
# 4            gini            None                      1
#
#   param_min_samples_split param_splitter  \
# 0                       2           best
# 1                       2         random
# 2                       3           best
# 3                       3         random
# 4                       4           best
#
#                                               params  split0_test_score  \
# 0  {'criterion': 'gini', 'max_depth': None, 'min_...             0.9125
# 1  {'criterion': 'gini', 'max_depth': None, 'min_...             0.9375
# 2  {'criterion': 'gini', 'max_depth': None, 'min_...             0.9125
# 3  {'criterion': 'gini', 'max_depth': None, 'min_...             0.9500
# 4  {'criterion': 'gini', 'max_depth': None, 'min_...             0.9125
#
#    split1_test_score  split2_test_score  split3_test_score  split4_test_score  \
# 0             0.8875             0.9000           0.936709           0.911392
# 1             0.9000             0.9625           0.911392           0.949367
# 2             0.8875             0.9000           0.936709           0.911392
# 3             0.9000             0.9625           0.924051           0.949367
# 4             0.8875             0.9000           0.936709           0.924051
#
#    mean_test_score  std_test_score  rank_test_score
# 0         0.909620        0.016292             1569
# 1         0.932152        0.023284              334
# 2         0.909620        0.016292             1569
# 3         0.937184        0.022400               46
# 4         0.912152        0.017321             1381

# %%
tuning_result_dt_gs.shape
# Out:
# (1980, 18)

# %%
dt_grid_search.best_params_ #clf = dt_grid_search.best_params_
# Out:
# {'criterion': 'entropy',
#  'max_depth': 6,
#  'min_samples_leaf': 1,
#  'min_samples_split': 9,
#  'splitter': 'random'}

# %%
tuning_result_dt_gs.sort_values('rank_test_score').head(5)
# Out:
#       mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 1275       0.002286      0.000403         0.002412        0.000205
# 1293       0.002794      0.000421         0.002009        0.000008
# 1190       0.006567      0.000845         0.003222        0.000685
# 1202       0.006643      0.000870         0.002537        0.000839
# 1200       0.006993      0.000887         0.002726        0.000967
#
#      param_criterion param_max_depth param_min_samples_leaf  \
# 1275         entropy               6                      1
# 1293         entropy               6                      2
# 1190         entropy               4                      2
# 1202         entropy               4                      2
# 1200         entropy               4                      2
#
#      param_min_samples_split param_splitter  \
# 1275                       9         random
# 1293                       9         random
# 1190                       3           best
# 1202                       9           best
# 1200                       8           best
#
#                                                  params  split0_test_score  \
# 1275  {'criterion': 'entropy', 'max_depth': 6, 'min_...             0.9375
# 1293  {'criterion': 'entropy', 'max_depth': 6, 'min_...             0.9375
# 1190  {'criterion': 'entropy', 'max_depth': 4, 'min_...             0.9375
# 1202  {'criterion': 'entropy', 'max_depth': 4, 'min_...             0.9375
# 1200  {'criterion': 'entropy', 'max_depth': 4, 'min_...             0.9375
#
#       split1_test_score  split2_test_score  split3_test_score  \
# 1275             0.9500             0.9375           0.949367
# 1293             0.9375             0.9500           0.949367
# 1190             0.9000             0.9750           0.949367
# 1202             0.9000             0.9750           0.949367
# 1200             0.9000             0.9750           0.949367
#
#       split4_test_score  mean_test_score  std_test_score  rank_test_score
# 1275           0.936709         0.942215        0.006108                1
# 1293           0.936709         0.942215        0.006108                1
# 1190           0.936709         0.939715        0.024205                3
# 1202           0.936709         0.939715        0.024205                3
# 1200           0.936709         0.939715        0.024205                3

# %% [markdown]
# # Perform Grid Search for Random Forest

# %% [markdown]
# rf_grid_search = GridSearchCV(estimator=RandomForestClassifier(random_state=42),
#                               param_grid=rf_params, cv=5)
# rf_grid_search.fit(xtrain, ytrain)

# %% [markdown]
# # Evaluate the optimized models

# %%
# Decision Tree and Grid Search
y_pred_dt_gs = dt_grid_search.predict(xtest)
print("\nDecision Tree Grid Search Performance:")
print("Accuracy:", accuracy_score(ytest, y_pred_dt_gs))
print("Classification Report:")
print(classification_report(ytest, y_pred_dt_gs))
# Out:
# Decision Tree Grid Search Performance:
# Accuracy: 0.9473684210526315
# Classification Report:
#               precision    recall  f1-score   support
#
#            B       0.95      0.97      0.96       108
#            M       0.95      0.90      0.93        63
#
#     accuracy                           0.95       171
#    macro avg       0.95      0.94      0.94       171
# weighted avg       0.95      0.95      0.95       171

# %% [markdown]
# # Random Forest Grid Search
# y_pred_rf_gs = rf_grid_search.predict(xtest)
# print("\nRandom Forest Grid Search Performance:")
# print("Accuracy:", accuracy_score(ytest, y_pred_rf_gs))
# print("Classification Report:")
# print(classification_report(ytest, y_pred_rf_gs))

# %% [markdown]
# # Hyperparameter optimization using Randomized Search for Decision Tree

# %%
# Perform Randomized Search for Decision Tree 
dt_random_search = RandomizedSearchCV(estimator=DecisionTreeClassifier(random_state=42), 
                                      param_distributions=dt_params, n_iter=100, cv=5, random_state=42) 
dt_random_search.fit(xtrain, ytrain)
# Out:
# RandomizedSearchCV(cv=5, estimator=DecisionTreeClassifier(random_state=42),
#                    n_iter=100,
#                    param_distributions={'criterion': ['gini', 'entropy'],
#                                         'max_depth': [None, 2, 4, 6, 8, 10, 12,
#                                                       15, 20, 25, 28],
#                                         'min_samples_leaf': [1, 2, 3, 4, 5],
#                                         'min_samples_split': [2, 3, 4, 5, 6, 7,
#                                                               8, 9, 10],
#                                         'splitter': ['best', 'random']},
#                    random_state=42)

# %%
dt_random_search.cv_results_
# Out:
# {'mean_fit_time': array([0.00682144, 0.00693021, 0.00220718, 0.00272484, 0.00784812,
#         0.00251198, 0.00762529, 0.00691857, 0.00241137, 0.00250793,
#         0.00552912, 0.00221472, 0.00251369, 0.00231028, 0.00704017,
#         0.00722895, 0.00663586, 0.0021069 , 0.00672059, 0.00743117,
#         0.00642567, 0.00744014, 0.00210452, 0.00230799, 0.00845456,
#         0.00272045, 0.00284028, 0.00250773, 0.00843167, 0.00779328,
#         0.00262117, 0.00231338, 0.00207124, 0.00736723, 0.00221705,
#         2.03698594e-04, 6.18229977e-04, 4.30806595e-04, 2.00162438e-04,
#         2.02552376e-04, 2.03540911e-04, 3.76949609e-04, 5.84741559e-04,
#         6.40882949e-04, 6.20550059e-04, 8.14208958e-04, 2.54440754e-04,
#         5.86478915e-04, 7.09743430e-04, 7.36204129e-04, 7.53463450e-04,
#         7.64850378e-04, 4.64189245e-04, 4.47615932e-04, 2.53739412e-04,
#         3.31291709e-04, 4.51503118e-04, 6.18696277e-04, 5.54814625e-04]),
#  'param_splitter': masked_array(data=['best', 'best', 'random', 'random', 'best', 'random',
#                     'best', 'best', 'random', 'random', 'best', 'random',
#                     'random', 'random', 'best', 'best', 'best', 'random',
#                     'best', 'best', 'best', 'best', 'random', 'random',
#                     'best', 'random', 'random', 'random', 'best', 'best',
#                     'random', 'random', 'random', 'best', 'random',
#                     'random', 'best', 'random', 'best', 'best', 'best',
#                     'best', 'best', 'random', 'best', 'best', 'best',
#                     'best', 'best', 'random', 'best', 'best', 'random',
#                     'random', 'best', 'random', 'best', 'random', 'best',
#                     'best', 'best', 'random', 'random', 'best', 'random',
#                     'best', 'random', 'random', 'best', 'random', 'random',
#                     'random', 'random', 'random', 'best', 'best', 'random',
#                     'random', 'best', 'random', 'random', 'random',
#                     'random', 'random', 'best', 'best', 'best', 'best',
#                     'best', 'best', 'best', 'best', 'best', 'best', 'best',
#                     'random', 'random', 'best', 'best', 'best'],
#               mask=[False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False],
#         fill_value='?',
#              dtype=object),
#  'param_min_samples_split': masked_array(data=[5, 3, 6, 5, 3, 7, 9, 2, 9, 9, 2, 7, 7, 8, 3, 10, 4, 6,
#                     8, 5, 2, 8, 7, 6, 8, 7, 10, 4, 6, 7, 9, 6, 8, 6, 5, 10,
#                     9, 3, 6, 10, 3, 10, 10, 4, 8, 2, 7, 9, 2, 2, 3, 4, 7,
#                     3, 5, 8, 5, 8, 2, 6, 8, 6, 4, 5, 7, 8, 7, 10, 9, 9, 9,
#                     8, 3, 7, 10, 3, 3, 10, 8, 8, 6, 3, 6, 3, 9, 10, 2, 5,
#                     4, 9, 5, 8, 9, 3, 2, 2, 5, 7, 5, 4],
#               mask=[False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False],
#         fill_value='?',
#              dtype=object),
#  'param_min_samples_leaf': masked_array(data=[5, 4, 5, 4, 2, 5, 1, 4, 2, 4, 3, 5, 2, 4, 5, 1, 4, 2,
#                     5, 3, 5, 1, 3, 5, 2, 5, 5, 5, 1, 1, 3, 4, 5, 1, 4, 2,
#                     3, 3, 2, 4, 3, 1, 3, 3, 2, 3, 5, 1, 1, 3, 2, 5, 1, 1,
#                     3, 3, 5, 3, 2, 1, 5, 1, 1, 4, 5, 2, 4, 4, 2, 2, 4, 4,
#                     2, 4, 3, 1, 2, 4, 2, 5, 4, 2, 1, 1, 3, 4, 2, 2, 4, 4,
#                     2, 2, 4, 1, 1, 2, 2, 3, 1, 3],
#               mask=[False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False],
#         fill_value='?',
#              dtype=object),
#  'param_max_depth': masked_array(data=[8, None, 6, 15, 20, 20, 10, 8, 15, None, 2, None, 8, 4,
#                     15, 10, 6, 2, 28, 12, 8, 10, 6, 2, 4, 10, 20, 10, 12,
#                     15, 4, 15, 8, 12, 20, 6, None, 12, 28, None, 2, 12, 28,
#                     4, 8, 28, 28, 6, 4, 6, 6, 20, 4, 15, 28, 28, 12, 25,
#                     10, 25, 6, None, 6, 20, 6, 12, None, 4, 4, None, 25, 8,
#                     12, 20, 25, 20, 2, 20, 4, 15, 12, 20, 2, 10, 15, 12,
#                     12, 15, 10, 8, 28, 25, 28, 8, 6, 6, 20, None, 8, 4],
#               mask=[False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False],
#         fill_value='?',
#              dtype=object),
#  'param_criterion': masked_array(data=['entropy', 'gini', 'gini', 'entropy', 'entropy',
#                     'entropy', 'gini', 'gini', 'entropy', 'gini',
#                     'entropy', 'entropy', 'entropy', 'gini', 'entropy',
#                     'entropy', 'entropy', 'entropy', 'gini', 'gini',
#                     'gini', 'gini', 'entropy', 'entropy', 'entropy',
#                     'entropy', 'gini', 'entropy', 'gini', 'entropy',
#                     'gini', 'gini', 'entropy', 'entropy', 'gini', 'gini',
#                     'entropy', 'gini', 'gini', 'gini', 'gini', 'entropy',
#                     'entropy', 'entropy', 'entropy', 'gini', 'entropy',
#                     'entropy', 'entropy', 'gini', 'entropy', 'entropy',
#                     'entropy', 'entropy', 'gini', 'gini', 'gini',
#                     'entropy', 'entropy', 'gini', 'gini', 'entropy',
#                     'gini', 'gini', 'gini', 'gini', 'entropy', 'gini',
#                     'gini', 'entropy', 'gini', 'entropy', 'gini', 'gini',
#                     'gini', 'gini', 'gini', 'entropy', 'gini', 'gini',
#                     'entropy', 'gini', 'gini', 'gini', 'gini', 'gini',
#                     'entropy', 'entropy', 'entropy', 'entropy', 'entropy',
#                     'entropy', 'gini', 'entropy', 'gini', 'gini',
#                     'entropy', 'entropy', 'gini', 'gini'],
#               mask=[False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False],
#         fill_value='?',
#              dtype=object),
#  'params': [{'splitter': 'best',
#    'min_samples_split': 5,
#    'min_samples_leaf': 5,
#    'max_depth': 8,
#    'criterion': 'entropy'},
#   {'splitter': 'best',
#    'min_samples_split': 3,
#    'min_samples_leaf': 4,
#    'max_depth': None,
#    'criterion': 'gini'},
#   {'splitter': 'random',
#    'min_samples_split': 6,
#    'min_samples_leaf': 5,
#    'max_depth': 6,
#    'criterion': 'gini'},
#   {'splitter': 'random',
#    'min_samples_split': 5,
#    'min_samples_leaf': 4,
#    'max_depth': 15,
#    'criterion': 'entropy'},
#   {'splitter': 'best',
#    'min_samples_split': 3,
#    'min_samples_leaf': 2,
#    'max_depth': 20,
#    'criterion': 'entropy'},
#   {'splitter': 'random',
#    'min_samples_split': 7,
#    'min_samples_leaf': 5,
#    'max_depth': 20,
#    'criterion': 'entropy'},
#   {'splitter': 'best',
#    'min_samples_split': 9,
#    'min_samples_leaf': 1,
#    'max_depth': 10,
#    'criterion': 'gini'},
#   {'splitter': 'best',
#    'min_samples_split': 2,
#    'min_samples_leaf': 4,
#    'max_depth': 8,
#    'criterion': 'gini'},
#   {'splitter': 'random',
#    'min_samples_split': 9,
#    'min_samples_leaf': 2,
#    'max_depth': 15,
#    'criterion': 'entropy'},
#   {'splitter': 'random',
#    'min_samples_split': 9,
#    'min_samples_leaf': 4,
#    'max_depth': None,
#    'criterion': 'gini'},
#   {'splitter': 'best',
#    'min_samples_split': 2,
#    'min_samples_leaf': 3,
#    'max_depth': 2,
#    'criterion': 'entropy'},
#   {'splitter': 'random',
#    'min_samples_split': 7,
#    'min_samples_leaf': 5,
#    'max_depth': None,
#    'criterion': 'entropy'},
#   {'splitter': 'random',
#    'min_samples_split': 7,
#    'min_samples_leaf': 2,
#    'max_depth': 8,
#    'criterion': 'entropy'},
#   {'splitter': 'random',
#    'min_samples_split': 8,
#    'min_samples_leaf': 4,
#    'max_depth': 4,
#    'criterion': 'gini'},
#   {'splitter': 'best',
#    'min_samples_split': 3,
#    'min_samples_leaf': 5,
#    'max_depth': 15,
#    'criterion': 'entropy'},
#   {'splitter': 'best',
#    'min_samples_split': 10,
#    'min_samples_leaf': 1,
#    'max_depth': 10,
#    'criterion': 'entropy'},
#   {'splitter': 'best',
#    'min_samples_split': 4,
#    'min_samples_leaf': 4,
#    'max_depth': 6,
#    'criterion': 'entropy'},
#   {'splitter': 'random',
#    'min_samples_split': 6,
#    'min_samples_leaf': 2,
#    'max_depth': 2,
#    'criterion': 'entropy'},
#   {'splitter': 'best',
#    'min_samples_split': 8,
#    'min_samples_leaf': 5,
#    'max_depth': 28,
#    'criterion': 'gini'},
#   {'splitter': 'best',
#    'min_samples_split': 5,
#    'min_samples_leaf': 3,
#    'max_depth': 12,
#    'criterion': 'gini'},
#   {'splitter': 'best',
#    'min_samples_split': 2,
#    'min_samples_leaf': 5,
#    'max_depth': 8,
#    'criterion': 'gini'},
#   {'splitter': 'best',
#    'min_samples_split': 8,
#    'min_samples_leaf': 1,
#    'max_depth': 10,
#    'criterion': 'gini'},
#   {'splitter': 'random',
#    'min_samples_split': 7,
#    'min_samples_leaf': 3,
#    'max_depth': 6,
#    'criterion': 'entropy'},
#   {'splitter': 'random',
#    'min_samples_split': 6,
#    'min_samples_leaf': 5,
#    'max_depth': 2,
#    'criterion': 'entropy'},
#   {'splitter': 'best',
#    'min_samples_split': 8,
#    'min_samples_leaf': 2,
#    'max_depth': 4,
#    'criterion': 'entropy'},
#   {'splitter': 'random',
#    'min_samples_split': 7,
#    'min_samples_leaf': 5,
#    'max_depth': 10,
#    'criterion': 'entropy'},
#   {'splitter': 'random',
#    'min_samples_split': 10,
#    'min_samples_leaf': 5,
#    'max_depth': 20,
#    'criterion': 'gini'},
#   {'splitter': 'random',
#    'min_samples_split': 4,
#    'min_samples_leaf': 5,
#    'max_depth': 10,
#    'criterion': 'entropy'},
#   {'splitter': 'best',
#    'min_samples_split': 6,
#    'min_samples_leaf': 1,
#    'max_depth': 12,
#    'criterion': 'gini'},
#   {'splitter': 'best',
#    'min_samples_split': 7,
#    'min_samples_leaf': 1,
#    'max_depth': 15,
#    'criterion': 'entropy'},
#   {'splitter': 'random',
#    'min_samples_split': 9,
#    'min_samples_leaf': 3,
#    'max_depth': 4,
#    'criterion': 'gini'},
#   {'splitter': 'random',
#    'min_samples_split': 6,
#    'min_samples_leaf': 4,
#    'max_depth': 15,
#    'criterion': 'gini'},
#   {'splitter': 'random',
#    'min_samples_split': 8,
#    'min_samples_leaf': 5,
#    'max_depth': 8,
#    'criterion': 'entropy'},
#   {'splitter': 'best',
#    'min_samples_split': 6,
#    'min_samples_leaf': 1,
#    'max_depth': 12,
#    'criterion': 'entropy'},
#   {'splitter': 'random',
#    'min_samples_split': 5,
#    'min_samples_leaf': 4,
#    'max_depth': 20,
#    'criterion': 'gini'},
#   {'splitter': 'random',
#    'min_samples_split': 10,
#    'min_samples_leaf': 2,
#    'max_depth': 6,
#    'criterion': 'gini'},
#   {'splitter': 'best',
#    'min_samples_split': 9,
#    'min_samples_leaf': 3,
#    'max_depth': None,
#    'criterion': 'entropy'},
#   {'splitter': 'random',
#    'min_samples_split': 3,
#    'min_samples_leaf': 3,
#    'max_depth': 12,
#    'criterion': 'gini'},
#   {'splitter': 'best',
#    'min_samples_split': 6,
#    'min_samples_leaf': 2,
#    'max_depth': 28,
#    'criterion': 'gini'},
#   {'splitter': 'best',
#    'min_samples_split': 10,
#    'min_samples_leaf': 4,
#    'max_depth': None,
#    'criterion': 'gini'},
#   {'splitter': 'best',
#    'min_samples_split': 3,
#    'min_samples_leaf': 3,
#    'max_depth': 2,
#    'criterion': 'gini'},
#   {'splitter': 'best',
#    'min_samples_split': 10,
#    'min_samples_leaf': 1,
#    'max_depth': 12,
#    'criterion': 'entropy'},
#   {'splitter': 'best',
#    'min_samples_split': 10,
#    'min_samples_leaf': 3,
#    'max_depth': 28,
#    'criterion': 'entropy'},
#   {'splitter': 'random',
#    'min_samples_split': 4,
#    'min_samples_leaf': 3,
#    'max_depth': 4,
#    'criterion': 'entropy'},
#   {'splitter': 'best',
#    'min_samples_split': 8,
#    'min_samples_leaf': 2,
#    'max_depth': 8,
#    'criterion': 'entropy'},
#   {'splitter': 'best',
#    'min_samples_split': 2,
#    'min_samples_leaf': 3,
#    'max_depth': 28,
#    'criterion': 'gini'},
#   {'splitter': 'best',
#    'min_samples_split': 7,
#    'min_samples_leaf': 5,
#    'max_depth': 28,
#    'criterion': 'entropy'},
#   {'splitter': 'best',
#    'min_samples_split': 9,
#    'min_samples_leaf': 1,
#    'max_depth': 6,
#    'criterion': 'entropy'},
#   {'splitter': 'best',
#    'min_samples_split': 2,
#    'min_samples_leaf': 1,
#    'max_depth': 4,
#    'criterion': 'entropy'},
#   {'splitter': 'random',
#    'min_samples_split': 2,
#    'min_samples_leaf': 3,
#    'max_depth': 6,
#    'criterion': 'gini'},
#   {'splitter': 'best',
#    'min_samples_split': 3,
#    'min_samples_leaf': 2,
#    'max_depth': 6,
#    'criterion': 'entropy'},
#   {'splitter': 'best',
#    'min_samples_split': 4,
#    'min_samples_leaf': 5,
#    'max_depth': 20,
#    'criterion': 'entropy'},
#   {'splitter': 'random',
#    'min_samples_split': 7,
#    'min_samples_leaf': 1,
#    'max_depth': 4,
#    'criterion': 'entropy'},
#   {'splitter': 'random',
#    'min_samples_split': 3,
#    'min_samples_leaf': 1,
#    'max_depth': 15,
#    'criterion': 'entropy'},
#   {'splitter': 'best',
#    'min_samples_split': 5,
#    'min_samples_leaf': 3,
#    'max_depth': 28,
#    'criterion': 'gini'},
#   {'splitter': 'random',
#    'min_samples_split': 8,
#    'min_samples_leaf': 3,
#    'max_depth': 28,
#    'criterion': 'gini'},
#   {'splitter': 'best',
#    'min_samples_split': 5,
#    'min_samples_leaf': 5,
#    'max_depth': 12,
#    'criterion': 'gini'},
#   {'splitter': 'random',
#    'min_samples_split': 8,
#    'min_samples_leaf': 3,
#    'max_depth': 25,
#    'criterion': 'entropy'},
#   {'splitter': 'best',
#    'min_samples_split': 2,
#    'min_samples_leaf': 2,
#    'max_depth': 10,
#    'criterion': 'entropy'},
#   {'splitter': 'best',
#    'min_samples_split': 6,
#    'min_samples_leaf': 1,
#    'max_depth': 25,
#    'criterion': 'gini'},
#   {'splitter': 'best',
#    'min_samples_split': 8,
#    'min_samples_leaf': 5,
#    'max_depth': 6,
#    'criterion': 'gini'},
#   {'splitter': 'random',
#    'min_samples_split': 6,
#    'min_samples_leaf': 1,
#    'max_depth': None,
#    'criterion': 'entropy'},
#   {'splitter': 'random',
#    'min_samples_split': 4,
#    'min_samples_leaf': 1,
#    'max_depth': 6,
#    'criterion': 'gini'},
#   {'splitter': 'best',
#    'min_samples_split': 5,
#    'min_samples_leaf': 4,
#    'max_depth': 20,
#    'criterion': 'gini'},
#   {'splitter': 'random',
#    'min_samples_split': 7,
#    'min_samples_leaf': 5,
#    'max_depth': 6,
#    'criterion': 'gini'},
#   {'splitter': 'best',
#    'min_samples_split': 8,
#    'min_samples_leaf': 2,
#    'max_depth': 12,
#    'criterion': 'gini'},
#   {'splitter': 'random',
#    'min_samples_split': 7,
#    'min_samples_leaf': 4,
#    'max_depth': None,
#    'criterion': 'entropy'},
#   {'splitter': 'random',
#    'min_samples_split': 10,
#    'min_samples_leaf': 4,
#    'max_depth': 4,
#    'criterion': 'gini'},
#   {'splitter': 'best',
#    'min_samples_split': 9,
#    'min_samples_leaf': 2,
#    'max_depth': 4,
#    'criterion': 'gini'},
#   {'splitter': 'random',
#    'min_samples_split': 9,
#    'min_samples_leaf': 2,
#    'max_depth': None,
#    'criterion': 'entropy'},
#   {'splitter': 'random',
#    'min_samples_split': 9,
#    'min_samples_leaf': 4,
#    'max_depth': 25,
#    'criterion': 'gini'},
#   {'splitter': 'random',
#    'min_samples_split': 8,
#    'min_samples_leaf': 4,
#    'max_depth': 8,
#    'criterion': 'entropy'},
#   {'splitter': 'random',
#    'min_samples_split': 3,
#    'min_samples_leaf': 2,
#    'max_depth': 12,
#    'criterion': 'gini'},
#   {'splitter': 'random',
#    'min_samples_split': 7,
#    'min_samples_leaf': 4,
#    'max_depth': 20,
#    'criterion': 'gini'},
#   {'splitter': 'best',
#    'min_samples_split': 10,
#    'min_samples_leaf': 3,
#    'max_depth': 25,
#    'criterion': 'gini'},
#   {'splitter': 'best',
#    'min_samples_split': 3,
#    'min_samples_leaf': 1,
#    'max_depth': 20,
#    'criterion': 'gini'},
#   {'splitter': 'random',
#    'min_samples_split': 3,
#    'min_samples_leaf': 2,
#    'max_depth': 2,
#    'criterion': 'gini'},
#   {'splitter': 'random',
#    'min_samples_split': 10,
#    'min_samples_leaf': 4,
#    'max_depth': 20,
#    'criterion': 'entropy'},
#   {'splitter': 'best',
#    'min_samples_split': 8,
#    'min_samples_leaf': 2,
#    'max_depth': 4,
#    'criterion': 'gini'},
#   {'splitter': 'random',
#    'min_samples_split': 8,
#    'min_samples_leaf': 5,
#    'max_depth': 15,
#    'criterion': 'gini'},
#   {'splitter': 'random',
#    'min_samples_split': 6,
#    'min_samples_leaf': 4,
#    'max_depth': 12,
#    'criterion': 'entropy'},
#   {'splitter': 'random',
#    'min_samples_split': 3,
#    'min_samples_leaf': 2,
#    'max_depth': 20,
#    'criterion': 'gini'},
#   {'splitter': 'random',
#    'min_samples_split': 6,
#    'min_samples_leaf': 1,
#    'max_depth': 2,
#    'criterion': 'gini'},
#   {'splitter': 'random',
#    'min_samples_split': 3,
#    'min_samples_leaf': 1,
#    'max_depth': 10,
#    'criterion': 'gini'},
#   {'splitter': 'best',
#    'min_samples_split': 9,
#    'min_samples_leaf': 3,
#    'max_depth': 15,
#    'criterion': 'gini'},
#   {'splitter': 'best',
#    'min_samples_split': 10,
#    'min_samples_leaf': 4,
#    'max_depth': 12,
#    'criterion': 'gini'},
#   {'splitter': 'best',
#    'min_samples_split': 2,
#    'min_samples_leaf': 2,
#    'max_depth': 12,
#    'criterion': 'entropy'},
#   {'splitter': 'best',
#    'min_samples_split': 5,
#    'min_samples_leaf': 2,
#    'max_depth': 15,
#    'criterion': 'entropy'},
#   {'splitter': 'best',
#    'min_samples_split': 4,
#    'min_samples_leaf': 4,
#    'max_depth': 10,
#    'criterion': 'entropy'},
#   {'splitter': 'best',
#    'min_samples_split': 9,
#    'min_samples_leaf': 4,
#    'max_depth': 8,
#    'criterion': 'entropy'},
#   {'splitter': 'best',
#    'min_samples_split': 5,
#    'min_samples_leaf': 2,
#    'max_depth': 28,
#    'criterion': 'entropy'},
#   {'splitter': 'best',
#    'min_samples_split': 8,
#    'min_samples_leaf': 2,
#    'max_depth': 25,
#    'criterion': 'entropy'},
#   {'splitter': 'best',
#    'min_samples_split': 9,
#    'min_samples_leaf': 4,
#    'max_depth': 28,
#    'criterion': 'gini'},
#   {'splitter': 'best',
#    'min_samples_split': 3,
#    'min_samples_leaf': 1,
#    'max_depth': 8,
#    'criterion': 'entropy'},
#   {'splitter': 'best',
#    'min_samples_split': 2,
#    'min_samples_leaf': 1,
#    'max_depth': 6,
#    'criterion': 'gini'},
#   {'splitter': 'random',
#    'min_samples_split': 2,
#    'min_samples_leaf': 2,
#    'max_depth': 6,
#    'criterion': 'gini'},
#   {'splitter': 'random',
#    'min_samples_split': 5,
#    'min_samples_leaf': 2,
#    'max_depth': 20,
#    'criterion': 'entropy'},
#   {'splitter': 'best',
#    'min_samples_split': 7,
#    'min_samples_leaf': 3,
#    'max_depth': None,
#    'criterion': 'entropy'},
#   {'splitter': 'best',
#    'min_samples_split': 5,
#    'min_samples_leaf': 1,
#    'max_depth': 8,
#    'criterion': 'gini'},
#   {'splitter': 'best',
#    'min_samples_split': 4,
#    'min_samples_leaf': 3,
#    'max_depth': 4,
#    'criterion': 'gini'}],
#  'split0_test_score': array([0.925 , 0.95  , 0.925 , 0.9125, 0.95  , 0.925 , 0.9375, 0.95  ,
#         0.9375, 0.925 , 0.9375, 0.925 , 0.9375, 0.9125, 0.925 , 0.9375,
#         0.95  , 0.9125, 0.9375, 0.95  , 0.9375, 0.9375, 0.9125, 0.9125,
#         0.9375, 0.925 , 0.9375, 0.925 , 0.9375, 0.925 , 0.9375, 0.925 ,
#         0.925 , 0.925 , 0.925 , 0.925 , 0.9375, 0.925 , 0.9375, 0.9375,
#         0.9   , 0.9375, 0.9375, 0.925 , 0.925 , 0.95  , 0.925 , 0.9375,
#         0.9375, 0.9125, 0.95  , 0.925 , 0.9375, 0.925 , 0.95  , 0.9   ,
#         0.9375, 0.925 , 0.95  , 0.9375, 0.9375, 0.9375, 0.9125, 0.95  ,
#         0.925 , 0.9375, 0.9125, 0.9125, 0.9375, 0.9375, 0.925 , 0.9125,
#         0.875 , 0.925 , 0.9375, 0.9125, 0.9125, 0.9125, 0.9375, 0.9375,
#         0.9125, 0.875 , 0.9125, 0.95  , 0.9375, 0.9375, 0.95  , 0.95  ,
#         0.95  , 0.925 , 0.95  , 0.925 , 0.9375, 0.95  , 0.9125, 0.95  ,
#         0.925 , 0.925 , 0.9125, 0.9375]),
#  'split1_test_score': array([0.8875, 0.9125, 0.875 , 0.875 , 0.9   , 0.875 , 0.8875, 0.9125,
head()
# Out:
#    mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0       0.006821      0.000598         0.002818        0.000604
# 1       0.006930      0.000927         0.002619        0.000809
# 2       0.002207      0.000817         0.002512        0.000322
# 3       0.002725      0.000401         0.002404        0.000490
# 4       0.007848      0.001128         0.003011        0.000899
#
#   param_splitter param_min_samples_split param_min_samples_leaf  \
# 0           best                       5                      5
# 1           best                       3                      4
# 2         random                       6                      5
# 3         random                       5                      4
# 4           best                       3                      2
#
#   param_max_depth param_criterion  \
# 0               8         entropy
# 1            None            gini
# 2               6            gini
# 3              15         entropy
# 4              20         entropy
#
#                                               params  split0_test_score  \
# 0  {'splitter': 'best', 'min_samples_split': 5, '...             0.9250
# 1  {'splitter': 'best', 'min_samples_split': 3, '...             0.9500
# 2  {'splitter': 'random', 'min_samples_split': 6,...             0.9250
# 3  {'splitter': 'random', 'min_samples_split': 5,...             0.9125
# 4  {'splitter': 'best', 'min_samples_split': 3, '...             0.9500
#
#    split1_test_score  split2_test_score  split3_test_score  split4_test_score  \
# 0             0.8875             0.9625           0.949367           0.924051
# 1             0.9125             0.9250           0.949367           0.924051
# 2             0.8750             0.9500           0.936709           0.860759
# 3             0.8750             0.9625           0.949367           0.936709
# 4             0.9000             0.9500           0.936709           0.936709
#
#    mean_test_score  std_test_score  rank_test_score
# 0         0.929684        0.025681               25
# 1         0.932184        0.014953               20
# 2         0.909494        0.035176               83
# 3         0.927215        0.030883               33
# 4         0.934684        0.018332                6

# %%
dt_random_search.best_params_
# Out:
# {'splitter': 'random',
#  'min_samples_split': 9,
#  'min_samples_leaf': 2,
#  'max_depth': 15,
#  'criterion': 'entropy'}

# %% [markdown]
# # Perform Randomized Search for Random Forest

# %%
rf_random_search = RandomizedSearchCV(estimator=RandomForestClassifier(random_state=42),
                                      param_distributions=rf_params, n_iter=100, cv=5, random_state=42)
rf_random_search.fit(xtrain, ytrain)
# Out:
# RandomizedSearchCV(cv=5, estimator=RandomForestClassifier(random_state=42),
#                    n_iter=100,
#                    param_distributions={'criterion': ['gini', 'entropy'],
#                                         'max_depth': [None, 2, 4, 6, 8, 10, 15,
#                                                       20, 25, 28],
#                                         'max_features': ['auto', 'sqrt',
#                                                          'log2'],
#                                         'min_samples_leaf': [1, 2, 3, 4],
#                                         'min_samples_split': [2, 3, 4, 5, 6, 7,
#                                                               810],
#                                         'n_estimators': [101, 151, 201, 251,
#                                                          301]},
#                    random_state=42)

# %%
rf_random_search.cv_results_
tuning_result_rf_rs = pd.DataFrame(rf_random_search.cv_results_)
tuning_result_rf_rs
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        0.000404      0.000495         0.000000        0.000000
# 1        0.113228      0.001432         0.012384        0.000135
# 2        0.219468      0.004352         0.016631        0.001853
# 3        0.309933      0.006621         0.019119        0.000677
# 4        0.000608      0.000497         0.000000        0.000000
# ..            ...           ...              ...             ...
# 95       0.197026      0.004829         0.012921        0.000576
# 96       0.263433      0.008078         0.016468        0.000609
# 97       0.219938      0.003806         0.022262        0.000728
# 98       0.000505      0.000637         0.000000        0.000000
# 99       0.000474      0.000590         0.000000        0.000000
#
#    param_n_estimators param_min_samples_split param_min_samples_leaf  \
# 0                 251                     810                      1
# 1                 151                     810                      3
# 2                 201                       4                      1
# 3                 251                       3                      3
# 4                 151                     810                      4
# ..                ...                     ...                    ...
# 95                151                       4                      1
# 96                201                       3                      2
# 97                301                     810                      1
# 98                201                       7                      2
# 99                251                       3                      4
#
#    param_max_features param_max_depth param_criterion  \
# 0                auto            None            gini
# 1                sqrt               4         entropy
# 2                log2               2         entropy
# 3                log2              20            gini
# 4                auto               2         entropy
# ..                ...             ...             ...
# 95               log2              28            gini
# 96               log2              28            gini
# 97               sqrt              20            gini
# 98               auto              15         entropy
# 99               auto               4         entropy
#
#                                                params  split0_test_score  \
# 0   {'n_estimators': 251, 'min_samples_split': 810...                NaN
# 1   {'n_estimators': 151, 'min_samples_split': 810...             0.6250
# 2   {'n_estimators': 201, 'min_samples_split': 4, ...             0.9375
# 3   {'n_estimators': 251, 'min_samples_split': 3, ...             0.9500
# 4   {'n_estimators': 151, 'min_samples_split': 810...                NaN
# ..                                                ...                ...
# 95  {'n_estimators': 151, 'min_samples_split': 4, ...             0.9375
# 96  {'n_estimators': 201, 'min_samples_split': 3, ...             0.9375
# 97  {'n_estimators': 301, 'min_samples_split': 810...             0.6250
# 98  {'n_estimators': 201, 'min_samples_split': 7, ...                NaN
# 99  {'n_estimators': 251, 'min_samples_split': 3, ...                NaN
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 0                 NaN                NaN                NaN
# 1              0.6250             0.6250           0.632911
# 2              0.9375             0.9375           0.936709
# 3              0.9500             0.9625           0.936709
# 4                 NaN                NaN                NaN
# ..                ...                ...                ...
# 95             0.9500             0.9625           0.936709
# 96             0.9500             0.9625           0.936709
# 97             0.6250             0.6250           0.632911
# 98                NaN                NaN                NaN
# 99                NaN                NaN                NaN
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0                 NaN              NaN             NaN               68
# 1            0.620253         0.625633        0.004077               57
# 2            0.924051         0.934652        0.005309               52
# 3            0.949367         0.949715        0.008160               15
# 4                 NaN              NaN             NaN               68
# ..                ...              ...             ...              ...
# 95           0.924051         0.942152        0.013073               50
# 96           0.949367         0.947215        0.009495               28
# 97           0.620253         0.625633        0.004077               57
# 98                NaN              NaN             NaN               68
# 99                NaN              NaN             NaN               68
#
# [100 rows x 19 columns]

# %%
rf_random_search.best_params_
# Out:
# {'n_estimators': 201,
#  'min_samples_split': 4,
#  'min_samples_leaf': 2,
#  'max_features': 'sqrt',
#  'max_depth': 8,
#  'criterion': 'gini'}

# %% [markdown]
# # Evaluate the optimized models for Randomized Search

# %% [markdown]
# # Decision Tree Randomized Search

# %%
y_pred_dt_rs = dt_random_search.predict(xtest)
print("\n Decision Tree Randomized Search Performance:")
print("Accuracy:", accuracy_score(ytest, y_pred_dt_rs))
print("Classification Report:")
print(classification_report(ytest, y_pred_dt_rs))
# Out:
#  Decision Tree Randomized Search Performance:
# Accuracy: 0.9590643274853801
# Classification Report:
#               precision    recall  f1-score   support
#
#            B       0.98      0.95      0.97       108
#            M       0.92      0.97      0.95        63
#
#     accuracy                           0.96       171
#    macro avg       0.95      0.96      0.96       171
# weighted avg       0.96      0.96      0.96       171

# %% [markdown]
# # Random Forest Randomized Search

# %%
y_pred_rf_rs = rf_random_search.predict(xtest)
print("\n Random Forest Randomized Search Performance:")
print("Accuracy:", accuracy_score(ytest, y_pred_rf_rs))
print("Classification Report:")
print(classification_report(ytest, y_pred_rf_rs))
# Out:
#  Random Forest Randomized Search Performance:
# Accuracy: 0.9707602339181286
# Classification Report:
#               precision    recall  f1-score   support
#
#            B       0.96      0.99      0.98       108
#            M       0.98      0.94      0.96        63
#
#     accuracy                           0.97       171
#    macro avg       0.97      0.96      0.97       171
# weighted avg       0.97      0.97      0.97       171

# %% [markdown]
# # Post Pruning for Decision Tree

# %%
dt_clf = dt_random_search.best_estimator_
dt_clf
# Out:
# DecisionTreeClassifier(criterion='entropy', max_depth=15, min_samples_leaf=2,
#                        min_samples_split=9, random_state=42, splitter='random')

# %%
from sklearn import tree
plt.figure(figsize=(15,10))
tree.plot_tree(dt_clf, filled=True, feature_names = x.columns)
# Out:
# [Text(0.4431818181818182, 0.9444444444444444, 'concave points_mean <= 0.04\nentropy = 0.954\nsamples = 398\nvalue = [249, 149]'),
#  Text(0.18181818181818182, 0.8333333333333334, 'radius_worst <= 17.727\nentropy = 0.248\nsamples = 218\nvalue = [209, 9]'),
#  Text(0.13636363636363635, 0.7222222222222222, 'concave points_mean <= 0.02\nentropy = 0.161\nsamples = 213\nvalue = [208, 5]'),
#  Text(0.09090909090909091, 0.6111111111111112, 'entropy = 0.0\nsamples = 96\nvalue = [96, 0]'),
#  Text(0.18181818181818182, 0.6111111111111112, 'radius_se <= 0.623\nentropy = 0.255\nsamples = 117\nvalue = [112, 5]'),
#  Text(0.13636363636363635, 0.5, 'perimeter_mean <= 79.994\nentropy = 0.176\nsamples = 114\nvalue = [111, 3]'),
#  Text(0.09090909090909091, 0.3888888888888889, 'entropy = 0.0\nsamples = 52\nvalue = [52, 0]'),
#  Text(0.18181818181818182, 0.3888888888888889, 'compactness_se <= 0.013\nentropy = 0.28\nsamples = 62\nvalue = [59, 3]'),
#  Text(0.13636363636363635, 0.2777777777777778, 'concavity_worst <= 0.214\nentropy = 0.592\nsamples = 21\nvalue = [18, 3]'),
#  Text(0.09090909090909091, 0.16666666666666666, 'concave points_worst <= 0.095\nentropy = 0.297\nsamples = 19\nvalue = [18, 1]'),
#  Text(0.045454545454545456, 0.05555555555555555, 'entropy = 0.0\nsamples = 15\nvalue = [15, 0]'),
#  Text(0.13636363636363635, 0.05555555555555555, 'entropy = 0.811\nsamples = 4\nvalue = [3, 1]'),
#  Text(0.18181818181818182, 0.16666666666666666, 'entropy = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.22727272727272727, 0.2777777777777778, 'entropy = 0.0\nsamples = 41\nvalue = [41, 0]'),
#  Text(0.22727272727272727, 0.5, 'entropy = 0.918\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.22727272727272727, 0.7222222222222222, 'entropy = 0.722\nsamples = 5\nvalue = [1, 4]'),
#  Text(0.7045454545454546, 0.8333333333333334, 'radius_worst <= 15.96\nentropy = 0.764\nsamples = 180\nvalue = [40, 140]'),
#  Text(0.5454545454545454, 0.7222222222222222, 'concave points_mean <= 0.062\nentropy = 0.947\nsamples = 41\nvalue = [26, 15]'),
#  Text(0.45454545454545453, 0.6111111111111112, 'compactness_worst <= 0.412\nentropy = 0.75\nsamples = 28\nvalue = [22, 6]'),
#  Text(0.4090909090909091, 0.5, 'perimeter_mean <= 90.058\nentropy = 0.529\nsamples = 25\nvalue = [22, 3]'),
#  Text(0.36363636363636365, 0.3888888888888889, 'texture_mean <= 21.237\nentropy = 0.276\nsamples = 21\nvalue = [20, 1]'),
#  Text(0.3181818181818182, 0.2777777777777778, 'entropy = 0.0\nsamples = 17\nvalue = [17, 0]'),
#  Text(0.4090909090909091, 0.2777777777777778, 'entropy = 0.811\nsamples = 4\nvalue = [3, 1]'),
#  Text(0.45454545454545453, 0.3888888888888889, 'entropy = 1.0\nsamples = 4\nvalue = [2, 2]'),
#  Text(0.5, 0.5, 'entropy = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.6363636363636364, 0.6111111111111112, 'texture_worst <= 20.467\nentropy = 0.89\nsamples = 13\nvalue = [4, 9]'),
#  Text(0.5909090909090909, 0.5, 'entropy = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.6818181818181818, 0.5, 'concavity_se <= 0.059\nentropy = 0.469\nsamples = 10\nvalue = [1, 9]'),
#  Text(0.6363636363636364, 0.3888888888888889, 'entropy = 0.0\nsamples = 8\nvalue = [0, 8]'),
#  Text(0.7272727272727273, 0.3888888888888889, 'entropy = 1.0\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.8636363636363636, 0.7222222222222222, 'concavity_worst <= 0.189\nentropy = 0.471\nsamples = 139\nvalue = [14, 125]'),
#  Text(0.8181818181818182, 0.6111111111111112, 'entropy = 0.0\nsamples = 6\nvalue = [6, 0]'),
#  Text(0.9090909090909091, 0.6111111111111112, 'concave points_worst <= 0.158\nentropy = 0.328\nsamples = 133\nvalue = [8, 125]'),
#  Text(0.8636363636363636, 0.5, 'area_worst <= 1055.35\nentropy = 0.702\nsamples = 42\nvalue = [8, 34]'),
#  Text(0.8181818181818182, 0.3888888888888889, 'texture_worst <= 20.192\nentropy = 0.991\nsamples = 18\nvalue = [8, 10]'),
#  Text(0.7727272727272727, 0.2777777777777778, 'entropy = 0.0\nsamples = 7\nvalue = [7, 0]'),
#  Text(0.8636363636363636, 0.2777777777777778, 'concave points_mean <= 0.052\nentropy = 0.439\nsamples = 11\nvalue = [1, 10]'),
#  Text(0.8181818181818182, 0.16666666666666666, 'entropy = 0.811\nsamples = 4\nvalue = [1, 3]'),
#  Text(0.9090909090909091, 0.16666666666666666, 'entropy = 0.0\nsamples = 7\nvalue = [0, 7]'),
#  Text(0.9090909090909091, 0.3888888888888889, 'entropy = 0.0\nsamples = 24\nvalue = [0, 24]'),
#  Text(0.9545454545454546, 0.5, 'entropy = 0.0\nsamples = 91\nvalue = [0, 91]')]

# %% [markdown]
# Read: #https://scikit-learn.org/stable/auto_examples/tree/plot_cost_complexity_pruning.html

# %%
pruning_path = dt_clf.cost_complexity_pruning_path(xtrain, ytrain) # clf = DecisionTreeClassifier  
ccp_alpha_values = pruning_path.ccp_alphas

# %%
ccp_alpha_values
# Out:
# array([0.        , 0.00399335, 0.00604739, 0.00641958, 0.00675868,
#        0.00862793, 0.01202884, 0.01435018, 0.0173026 , 0.01763119,
#        0.03099137, 0.03549229, 0.04094249, 0.05496803, 0.08343007,
#        0.47242814])

# %%
clfs_list = []  # save models with diffrent ccp_alpha value
for ccp in ccp_alpha_values:
    clf = DecisionTreeClassifier(random_state=42, ccp_alpha=ccp)
    clf.fit(xtrain, ytrain)
    clfs_list.append(clf)

# %%
clfs_list
# Out:
# [DecisionTreeClassifier(random_state=42),
#  DecisionTreeClassifier(ccp_alpha=0.003993352659045518, random_state=42),
#  DecisionTreeClassifier(ccp_alpha=0.006047387516658223, random_state=42),
#  DecisionTreeClassifier(ccp_alpha=0.006419576589874848, random_state=42),
#  DecisionTreeClassifier(ccp_alpha=0.006758683256012092, random_state=42),
#  DecisionTreeClassifier(ccp_alpha=0.00862793379793314, random_state=42),
#  DecisionTreeClassifier(ccp_alpha=0.012028844403926979, random_state=42),
#  DecisionTreeClassifier(ccp_alpha=0.014350184435176862, random_state=42),
#  DecisionTreeClassifier(ccp_alpha=0.017302601474775314, random_state=42),
#  DecisionTreeClassifier(ccp_alpha=0.01763119048807507, random_state=42),
#  DecisionTreeClassifier(ccp_alpha=0.030991367208617764, random_state=42),
#  DecisionTreeClassifier(ccp_alpha=0.03549229443392196, random_state=42),
#  DecisionTreeClassifier(ccp_alpha=0.04094249107720667, random_state=42),
#  DecisionTreeClassifier(ccp_alpha=0.05496803084950469, random_state=42),
#  DecisionTreeClassifier(ccp_alpha=0.08343006525378449, random_state=42),
#  DecisionTreeClassifier(ccp_alpha=0.47242813564703956, random_state=42)]

# %%
train_scores = [ clf.score(xtrain, ytrain) for clf in clfs_list ] 
test_scores = [ clf.score(xtest, ytest) for clf in clfs_list ]

# %%
train_scores
# Out:
# [1.0,
#  0.992462311557789,
#  0.9899497487437185,
#  0.9874371859296482,
#  0.9874371859296482,
#  0.9824120603015075,
#  0.9698492462311558,
#  0.9698492462311558,
#  0.9422110552763819,
#  0.9422110552763819,
#  0.9246231155778895,
#  0.9246231155778895,
#  0.9246231155778895,
#  0.9246231155778895,
#  0.9246231155778895,
#  0.6256281407035176]

# %%
test_scores
# Out:
# [0.9415204678362573,
#  0.9590643274853801,
#  0.9649122807017544,
#  0.9649122807017544,
#  0.9649122807017544,
#  0.9649122807017544,
#  0.9590643274853801,
#  0.9590643274853801,
#  0.9298245614035088,
#  0.9298245614035088,
#  0.8947368421052632,
#  0.8947368421052632,
#  0.8947368421052632,
#  0.8947368421052632,
#  0.8947368421052632,
#  0.631578947368421]

# %%
import matplotlib.pyplot as plt

# %%
fig, ax = plt.subplots()
ax.set_xlabel("Alpha")
ax.set_ylabel("Accuracy")

ax.plot(ccp_alpha_values, train_scores, marker='o', label="training accuracy", drawstyle="steps-post")
ax.plot(ccp_alpha_values, test_scores, marker='o', label="testing accuracy", drawstyle="steps-post")
ax.legend()

# %%
clf = DecisionTreeClassifier(random_state=42, ccp_alpha=0.01)
clf.fit(xtrain, ytrain)
# Out:
# DecisionTreeClassifier(ccp_alpha=0.01, random_state=42)

# %%
pred = clf.predict(xtest)
accuracy_score(ytest, pred)
# Out:
# 0.9649122807017544

# %%
clf.score(xtrain, ytrain)
# Out:
# 0.9824120603015075

# %%
plt.figure(figsize=(15,10))
tree.plot_tree(clf, filled=True, feature_names = x.columns)
# Out:
# [Text(0.4230769230769231, 0.9, 'concave points_mean <= 0.051\ngini = 0.468\nsamples = 398\nvalue = [249, 149]'),
#  Text(0.15384615384615385, 0.7, 'radius_worst <= 16.83\ngini = 0.1\nsamples = 245\nvalue = [232, 13]'),
#  Text(0.07692307692307693, 0.5, 'gini = 0.043\nsamples = 230\nvalue = [225, 5]'),
#  Text(0.23076923076923078, 0.5, 'texture_mean <= 16.19\ngini = 0.498\nsamples = 15\nvalue = [7, 8]'),
#  Text(0.15384615384615385, 0.3, 'gini = 0.0\nsamples = 5\nvalue = [5, 0]'),
#  Text(0.3076923076923077, 0.3, 'gini = 0.32\nsamples = 10\nvalue = [2, 8]'),
#  Text(0.6923076923076923, 0.7, 'texture_worst <= 20.405\ngini = 0.198\nsamples = 153\nvalue = [17, 136]'),
#  Text(0.5384615384615384, 0.5, 'radius_worst <= 18.145\ngini = 0.408\nsamples = 14\nvalue = [10, 4]'),
#  Text(0.46153846153846156, 0.3, 'gini = 0.0\nsamples = 10\nvalue = [10, 0]'),
#  Text(0.6153846153846154, 0.3, 'gini = 0.0\nsamples = 4\nvalue = [0, 4]'),
#  Text(0.8461538461538461, 0.5, 'area_worst <= 718.65\ngini = 0.096\nsamples = 139\nvalue = [7, 132]'),
#  Text(0.7692307692307693, 0.3, 'texture_worst <= 25.925\ngini = 0.497\nsamples = 13\nvalue = [7, 6]'),
#  Text(0.6923076923076923, 0.1, 'gini = 0.0\nsamples = 7\nvalue = [7, 0]'),
#  Text(0.8461538461538461, 0.1, 'gini = 0.0\nsamples = 6\nvalue = [0, 6]'),
#  Text(0.9230769230769231, 0.3, 'gini = 0.0\nsamples = 126\nvalue = [0, 126]')]

# %% [markdown]
# # XGBoost

# %%
# random & grid
# before performance & after performance

# %%
# xtrain, xtest, ytrain, ytest

# %%
#!pip install xgboost

# %% [markdown]
# # ADA Boost

# %%
# random & grid
# before performance & after performance

# %% [markdown]
# # CatBoost

# %%
# random & grid
# before performance & after performance
